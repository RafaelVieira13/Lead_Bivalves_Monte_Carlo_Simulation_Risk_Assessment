# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
biv=pd.read_excel("Chumbo_MBV_2013_2022-PNCA-ASAE.xlsx")

# %%
biv
# Out:
#      Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 0         True        63015      1803338  0088A3394P18      PNCA
# 1         True        21140      1306508  0091A3182L13      PNCA
# 2         True        24895      1400840  0015A3030L14      PNCA
# 3         True        63011      1803334  0077A3272P18      PNCA
# 4         True        63009      1803332  0073A3272P18      PNCA
# ..         ...          ...          ...           ...       ...
# 112       True        67206      1807430  0214A3272P18      PNCA
# 113       True        37913      1504717  0008A0384L15      PNCA
# 114       True        67377      1807589  0226A3272P18      PNCA
# 115       True        40747      1507498  0145A3202P15      PNCA
# 116       True        63045      1803368  0081A3078L18      PNCA
#
#          Tipo de Amostra                               Descrição da Amostra  \
# 0                Amêijoa  Ameijoa Vietnimita branca c/ casca fervida con...
# ...

# %%
biv.describe()
# Out:
#         ID Colheita   Nr. Amostra
# count  1.170000e+02  1.170000e+02
# mean   8.083938e+04  1.606832e+06
# std    2.684633e+05  1.861017e+05
# min    2.114000e+04  1.306508e+06
# 25%    3.416200e+04  1.501022e+06
# 50%    4.545600e+04  1.603260e+06
# 75%    6.294100e+04  1.803265e+06
# max    2.104486e+06  2.104387e+06

# %%
biv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Validado              117 non-null    bool
#  1   ID Colheita           117 non-null    int64
#  2   Nr. Amostra           117 non-null    int64
#  3   Lote                  117 non-null    object
#  4   Controlo              117 non-null    object
#  5   Tipo de Amostra       117 non-null    object
#  6   Descrição da Amostra  78 non-null     object
#  7   Parâmetro             117 non-null    object
#  8   Res.Trat.             117 non-null    object
#  9   Unidade               117 non-null    object
#  10  Método                117 non-null    object
#  11  Data Resultado        117 non-null    datetime64[ns]
#  12  Data Entrada Lab.     117 non-null    datetime64[ns]
#  13  Data Colheita         117 non-null    datetime64[ns]
# ...

# %% [markdown]
# # Valores Na

# %%
biv.isnull().sum()
# Out:
# Validado                 0
# ID Colheita              0
# Nr. Amostra              0
# Lote                     0
# Controlo                 0
# Tipo de Amostra          0
# Descrição da Amostra    39
# Parâmetro                0
# Res.Trat.                0
# Unidade                  0
# Método                   0
# Data Resultado           0
# Data Entrada Lab.        0
# Data Colheita            0
# Unidades Lab.            0
# dtype: int64

# %% [markdown]
# # Limpar Valores LD

# %% [raw]
# Dados da Coluna "Res.Trat." que contenham a string "LD"

# %%
#Filtrar Dados da Coluna "Res.Trat." que contenham a string "LD"
LD=biv[biv["Res.Trat."].str.contains("LD", regex = False)]
LD
# Out:
#      Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 94        True        21437      1306803  0215A2242L13      PNCA
# 95        True        21606      1306967  0165A2232E13      PNCA
# 106       True        31659      1407500  0235A2232F14      PNCA
# 107       True        45455      1603259  0066A3078L16      PNCA
# 108       True        45621      1603422  0061A3078F16      PNCA
# 109       True        40744      1507485  0140A3202P15      PNCA
# 110       True        47552      1605319  0288A3051C16      PNCA
# 111       True        67138      1807364  0216A3272P18      PNCA
# 112       True        67206      1807430  0214A3272P18      PNCA
# 113       True        37913      1504717  0008A0384L15      PNCA
# 114       True        67377      1807589  0226A3272P18      PNCA
# 115       True        40747      1507498  0145A3202P15      PNCA
# 116       True        63045      1803368  0081A3078L18      PNCA
#
# ...

# %%
# Eliminar Dados da Coluna "Res.Trat." que contenham a string "LD" da DataFrame Original
bivf= biv.drop(LD.index)
bivf
# Out:
#      Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 0         True        63015      1803338  0088A3394P18      PNCA
# 1         True        21140      1306508  0091A3182L13      PNCA
# 2         True        24895      1400840  0015A3030L14      PNCA
# 3         True        63011      1803334  0077A3272P18      PNCA
# 4         True        63009      1803332  0073A3272P18      PNCA
# ..         ...          ...          ...           ...       ...
# 101       True        68277      1900753  0032A3148C19      PNCA
# 102       True        37918      1504722  0007A0384L15      PNCA
# 103       True        37686      1504483  0116A2232L15      PNCA
# 104       True        47411      1605181  0267A3051C16      PNCA
# 105       True        47542      1605309  0247A3051C16      PNCA
#
#           Tipo de Amostra                               Descrição da Amostra  \
# 0                 Amêijoa  Ameijoa Vietnimita branca c/ casca fervida con...
# ...

# %%
#Verificar se dados foram eliminados
bivf[bivf["Res.Trat."].str.contains("LD", regex = False)]
# Out:
# Empty DataFrame
# Columns: [Validado , ID Colheita, Nr. Amostra, Lote, Controlo , Tipo de Amostra, Descrição da Amostra, Parâmetro, Res.Trat., Unidade, Método, Data Resultado, Data Entrada Lab., Data Colheita, Unidades Lab.]
# Index: []

# %% [markdown]
# # Ánalise Explorátoria

# %% [raw]
# 1-Ver Categoria de Amostras:

# %%
bivf["Tipo de Amostra"].value_counts().head(40)
# Out:
# Amêijoa                              40
# Ostra, vivo                          13
# Mexilhão                             12
# Mexilhão, vivo                        8
# Amêijoa-japonesa, vivo                5
# Amêijoa-boa, vivo                     4
# Amêijoa-branca, vivo                  3
# Ostra                                 2
# Amêijoa, vivo                         2
# Amêijoa-vietnamita, congelado         2
# Lambujinha, vivo                      2
# Berbigão                              2
# Amêijoa-branca, congelado             2
# Mexilhão, com outra transformação     2
# Moluscos bivalves                     1
# Longueirão, vivo                      1
# Navalheira, Caranguejo cozido         1
# Amêijoa-japonesa, congelado           1
# Longueirão                            1
# Name: Tipo de Amostra, dtype: int64

# %%
sns.set_style("whitegrid")
sns.countplot(y="Tipo de Amostra", data=bivf)
plt.xlabel("Nº de Amostras")
plt.ylabel("Tipo de Amostras")
plt.title("Número de Amostras por Tipo de Amostra")
plt.xticks(range(0,50,2), size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
bivf["Descrição da Amostra"].value_counts()
# Out:
# Mexilhão                                                       3
# Vietnamita Congelada                                           3
# Ameijoa Boa                                                    2
# Vietnamita                                                     2
# Vietnamita congelada                                           2
# Ameijoa Japonesa                                               2
# Ultracongelado                                                 2
# Miolo de ameijoa                                               2
# Vietnamita branca                                              2
# Ameijoa Japonesa ultracongelada                                2
# Ameijoa Branca Nac. Ultracongelada                             1
# Miolo de ameijoa Zebra cozida                                  1
# Japonesa Congelada                                             1
# em escabeche                                                   1
# ...

# %%
plt.figure(figsize=(10,15))
sns.set_style("whitegrid")
sns.countplot(y="Descrição da Amostra",data=bivf)
plt.xlabel("Nº de Amostras")
plt.title("Número de Amostras por Descrição da Amostra")
plt.yticks(size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
bivf["Tipo de Amostra"].value_counts()
# Out:
# Amêijoa                              40
# Ostra, vivo                          13
# Mexilhão                             12
# Mexilhão, vivo                        8
# Amêijoa-japonesa, vivo                5
# Amêijoa-boa, vivo                     4
# Amêijoa-branca, vivo                  3
# Ostra                                 2
# Amêijoa, vivo                         2
# Amêijoa-vietnamita, congelado         2
# Lambujinha, vivo                      2
# Berbigão                              2
# Amêijoa-branca, congelado             2
# Mexilhão, com outra transformação     2
# Moluscos bivalves                     1
# Longueirão, vivo                      1
# Navalheira, Caranguejo cozido         1
# Amêijoa-japonesa, congelado           1
# Longueirão                            1
# Name: Tipo de Amostra, dtype: int64

# %% [markdown]
# # Dados Duplicados

# %%
bivf.head()
# Out:
#    Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 0       True        63015      1803338  0088A3394P18      PNCA
# 1       True        21140      1306508  0091A3182L13      PNCA
# 2       True        24895      1400840  0015A3030L14      PNCA
# 3       True        63011      1803334  0077A3272P18      PNCA
# 4       True        63009      1803332  0073A3272P18      PNCA
#
#     Tipo de Amostra                               Descrição da Amostra  \
# 0           Amêijoa  Ameijoa Vietnimita branca c/ casca fervida con...
# 1  Lambujinha, vivo                                                NaN
# 2  Lambujinha, vivo                                                NaN
# 3          Mexilhão             Mexilhão inteiro cozido ultracongelado
# 4           Amêijoa  Ameijoa Vietnamita inteira fervida ultracongelada
#
#        Parâmetro Res.Trat. Unidade                Método  \
# 0  Chumbo  (LFQ)       1,2   mg/kg  QMI 02 de 14/03/2019
# ...

# %%
bivf[bivf.duplicated(["Nr. Amostra"], keep =False)]
# Out:
# Empty DataFrame
# Columns: [Validado , ID Colheita, Nr. Amostra, Lote, Controlo , Tipo de Amostra, Descrição da Amostra, Parâmetro, Res.Trat., Unidade, Método, Data Resultado, Data Entrada Lab., Data Colheita, Unidades Lab.]
# Index: []

# %% [markdown]
# # Eliminar Espécies que não são bivalves

# %%
# Navalheira, Caranguejo cozido
navalheira =bivf[bivf["Tipo de Amostra"] == "Navalheira, Caranguejo cozido"]
bivf1= bivf.drop(navalheira.index)
bivf1["Tipo de Amostra"].value_counts()
# Out:
# Amêijoa                              40
# Ostra, vivo                          13
# Mexilhão                             12
# Mexilhão, vivo                        8
# Amêijoa-japonesa, vivo                5
# Amêijoa-boa, vivo                     4
# Amêijoa-branca, vivo                  3
# Ostra                                 2
# Amêijoa, vivo                         2
# Amêijoa-vietnamita, congelado         2
# Lambujinha, vivo                      2
# Berbigão                              2
# Amêijoa-branca, congelado             2
# Mexilhão, com outra transformação     2
# Moluscos bivalves                     1
# Longueirão, vivo                      1
# Amêijoa-japonesa, congelado           1
# Longueirão                            1
# Name: Tipo de Amostra, dtype: int64

# %%
bivf1
# Out:
#      Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 0         True        63015      1803338  0088A3394P18      PNCA
# 1         True        21140      1306508  0091A3182L13      PNCA
# 2         True        24895      1400840  0015A3030L14      PNCA
# 3         True        63011      1803334  0077A3272P18      PNCA
# 4         True        63009      1803332  0073A3272P18      PNCA
# ..         ...          ...          ...           ...       ...
# 101       True        68277      1900753  0032A3148C19      PNCA
# 102       True        37918      1504722  0007A0384L15      PNCA
# 103       True        37686      1504483  0116A2232L15      PNCA
# 104       True        47411      1605181  0267A3051C16      PNCA
# 105       True        47542      1605309  0247A3051C16      PNCA
#
#           Tipo de Amostra                               Descrição da Amostra  \
# 0                 Amêijoa  Ameijoa Vietnimita branca c/ casca fervida con...
# ...

# %% [markdown]
# # Padronizar Dados pela coluna de Descrição

# %%
bivf1["Descrição da Amostra"].value_counts()
# Out:
# Mexilhão                                                       3
# Vietnamita Congelada                                           3
# Ameijoa Japonesa ultracongelada                                2
# Vietnamita branca                                              2
# Miolo de ameijoa                                               2
# Ameijoa Boa                                                    2
# Vietnamita congelada                                           2
# Vietnamita                                                     2
# Ameijoa Japonesa                                               2
# Ameijoa branca inteira cozida 60/80                            1
# em escabeche                                                   1
# Ameijoa Branca Nac. Ultracongelada                             1
# Miolo de ameijoa Zebra cozida                                  1
# Japonesa Congelada                                             1
# ...

# %%
bivf1.loc[bivf1['Descrição da Amostra'].isin( ['Vietnamita Congelada',
                                               "Vietnamita branca",
                                               "Vietnamita congelada",
                                               "Vietnamita",
                                               "Ameijoa Vietnamita Castanha ( menetripLyrata)",
                                               "Ameijoa Vietnimita branca c/ casca fervida congelada",
                                               "Vietnamita Congelada Pré-Cozida",
                                               "Amêijoa vietnamita ultracongelada - Meretrix Lyrata",
                                               "Castanha Vietnamita",
                                               "Ameijoa Vietnamita inteira fervida ultracongelada",
                                               "Ameijoa Vietnimita branca",
                                               "Vietnamita com casca,Fervida, Ultracongelada",
                                               "Vietnamita Branca Cozida e inteira",
                                               "Vietnamita cozida ultracongelada",
                                               "Vietnamita Inteira Fervida Ultracongelada",
                                               "Amêijoa Vietnamita c/ casca Ultracongelada",
                                               "Amêijoa Vietnamita Fervida Congelada",
                                               "Amêijoa vietnamita c/ casca fervida congelada",
                                               "Ameijoa Vietnamita congelada 60/80",
                                               "Vietnamita Branca Congelada (Meretrix Lyrata)",
                                               "Vietnamita castanha cozida ultracongelada",
                                               "Vietnamita branca com casca escaldada ultracongelada",
                                               "Vietnamita castanha"
                                               "Amêijoa Vietnamita Fervida Ultracongelada",
                                               "Ameijoa Vietnamita"
                                               'Ameijoa Vietnimita branca c/ casca fervida congelada',
                                              "Vietnamita castanha",
                                              "Amêijoa Vietnamita Fervida Ultracongelada"]), 'Descrição da Amostra'] = "Amêijoa-vietnamita"

# %%
bivf1
# Out:
#      Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 0         True        63015      1803338  0088A3394P18      PNCA
# 1         True        21140      1306508  0091A3182L13      PNCA
# 2         True        24895      1400840  0015A3030L14      PNCA
# 3         True        63011      1803334  0077A3272P18      PNCA
# 4         True        63009      1803332  0073A3272P18      PNCA
# ..         ...          ...          ...           ...       ...
# 101       True        68277      1900753  0032A3148C19      PNCA
# 102       True        37918      1504722  0007A0384L15      PNCA
# 103       True        37686      1504483  0116A2232L15      PNCA
# 104       True        47411      1605181  0267A3051C16      PNCA
# 105       True        47542      1605309  0247A3051C16      PNCA
#
#           Tipo de Amostra                               Descrição da Amostra  \
# 0                 Amêijoa                                 Amêijoa-vietnamita
# ...

# %%
bivf1["Descrição da Amostra"].value_counts()
# Out:
# Amêijoa-vietnamita                                             29
# Mexilhão                                                        3
# Ameijoa Boa                                                     2
# Ameijoa Japonesa ultracongelada                                 2
# Miolo de ameijoa                                                2
# Ameijoa Japonesa                                                2
# Miolo de Mexilhão pré-cozido e ultracongelado                   1
# Amêijoa Boa                                                     1
# Ameijoa branca                                                  1
# Ultracongelado                                                  1
# Branca congelada                                                1
# Amêijoa japonesa 60/80 (Ruditapes philippinarum)                1
# Amêijoa Japonesa                                                1
# Ostra Fina (Crassostrea Gigas)                                  1
# ...

# %%
# Mexilhão
bivf1.loc[bivf1['Descrição da Amostra'].isin( ["Mexilhão 1/2 concha da Nova Zelândia",
                                               "Miolo de Mexilhão pré-cozido e ultracongelado",
                                               "Mexilhão 1/2 concha da Nova Zelândia",
                                               "Miolo de mexilhão ultracongelado",
                                               "Mexilhão inteiro cozido ultracongelado",
                                               "Miolo de mexilhão",
                                               "Miolo de mexilhão cozido ultracongelado",
                                               "Carne de Mexilhão cozida - Aquicultura",
                                               "Miolo de Mexilhão pré -cozido ultracongelado de Aquicultura"]), 'Descrição da Amostra'] = "Mexilhão"

# %%
bivf1
# Out:
#      Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 0         True        63015      1803338  0088A3394P18      PNCA
# 1         True        21140      1306508  0091A3182L13      PNCA
# 2         True        24895      1400840  0015A3030L14      PNCA
# 3         True        63011      1803334  0077A3272P18      PNCA
# 4         True        63009      1803332  0073A3272P18      PNCA
# ..         ...          ...          ...           ...       ...
# 101       True        68277      1900753  0032A3148C19      PNCA
# 102       True        37918      1504722  0007A0384L15      PNCA
# 103       True        37686      1504483  0116A2232L15      PNCA
# 104       True        47411      1605181  0267A3051C16      PNCA
# 105       True        47542      1605309  0247A3051C16      PNCA
#
#           Tipo de Amostra             Descrição da Amostra      Parâmetro  \
# 0                 Amêijoa               Amêijoa-vietnamita  Chumbo  (LFQ)
# ...

# %%
bivf1["Descrição da Amostra"].value_counts()
# Out:
# Amêijoa-vietnamita                                  29
# Mexilhão                                            11
# Ameijoa Japonesa ultracongelada                      2
# Ameijoa Boa                                          2
# Miolo de ameijoa                                     2
# Ameijoa Japonesa                                     2
# Ameijoa branca                                       1
# Ultracongelado                                       1
# Branca congelada                                     1
# Amêijoa japonesa 60/80 (Ruditapes philippinarum)     1
# Amêijoa Japonesa                                     1
# Ostra Fina (Crassostrea Gigas)                       1
# Ostras frescas                                       1
# da Ria                                               1
# Japonesa Congelada                                   1
# Miolo de ameijoa Zebra cozida                        1
# Ameijoa Branca Nac. Ultracongelada                   1
# ...

# %%
# Amêijoa- boa
bivf1.loc[bivf1["Descrição da Amostra"].isin ( [ "Ameijoa Boa",
                                                 "Amêijoa Boa"] ), "Descrição da Amostra"] = "Amêijoa-boa"
bivf1["Descrição da Amostra"].value_counts()
# Out:
# Amêijoa-vietnamita                                  29
# Mexilhão                                            11
# Amêijoa-boa                                          3
# Ameijoa Japonesa                                     2
# Miolo de ameijoa                                     2
# Ameijoa Japonesa ultracongelada                      2
# Ultracongelado                                       1
# Branca congelada                                     1
# Amêijoa japonesa 60/80 (Ruditapes philippinarum)     1
# Amêijoa Japonesa                                     1
# Ostra Fina (Crassostrea Gigas)                       1
# Ostras frescas                                       1
# da Ria                                               1
# Japonesa Congelada                                   1
# Miolo de ameijoa Zebra cozida                        1
# Ameijoa Branca Nac. Ultracongelada                   1
# em escabeche                                         1
# ...

# %%
bivf1
# Out:
#      Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 0         True        63015      1803338  0088A3394P18      PNCA
# 1         True        21140      1306508  0091A3182L13      PNCA
# 2         True        24895      1400840  0015A3030L14      PNCA
# 3         True        63011      1803334  0077A3272P18      PNCA
# 4         True        63009      1803332  0073A3272P18      PNCA
# ..         ...          ...          ...           ...       ...
# 101       True        68277      1900753  0032A3148C19      PNCA
# 102       True        37918      1504722  0007A0384L15      PNCA
# 103       True        37686      1504483  0116A2232L15      PNCA
# 104       True        47411      1605181  0267A3051C16      PNCA
# 105       True        47542      1605309  0247A3051C16      PNCA
#
#           Tipo de Amostra             Descrição da Amostra      Parâmetro  \
# 0                 Amêijoa               Amêijoa-vietnamita  Chumbo  (LFQ)
# ...

# %%
# Amêijoa-japonesa
bivf1.loc[bivf1["Descrição da Amostra"].isin ( [ "Ameijoa Japonesa",
                                                "Ameijoa Japonesa ultracongelada",
                                                "Amêijoa Japonesa",
                                                "Japonesa Congelada",
                                                "Amêijoa japonesa 60/80 (Ruditapes philippinarum)"]), "Descrição da Amostra"] = "Amêijoa-japonesa"
bivf1["Descrição da Amostra"].value_counts()
# Out:
# Amêijoa-vietnamita                               29
# Mexilhão                                         11
# Amêijoa-japonesa                                  7
# Amêijoa-boa                                       3
# Miolo de ameijoa                                  2
# Pré-cozinhada                                     1
# Castanholas                                       1
# Ameijoa branca inteira cozida 60/80               1
# em escabeche                                      1
# Ameijoa Branca Nac. Ultracongelada                1
# Canivetes                                         1
# Miolo de ameijoa Zebra cozida                     1
# Miolo de ameijoa Zebra fervida ultracongelada     1
# da Ria                                            1
# Ostras frescas                                    1
# Ostra Fina (Crassostrea Gigas)                    1
# em Escabeche                                      1
# Branca congelada                                  1
# ...

# %%
bivf1["Descrição da Amostra"].value_counts()
# Out:
# Amêijoa-vietnamita                               29
# Mexilhão                                         11
# Amêijoa-japonesa                                  7
# Amêijoa-boa                                       3
# Miolo de ameijoa                                  2
# Pré-cozinhada                                     1
# Castanholas                                       1
# Ameijoa branca inteira cozida 60/80               1
# em escabeche                                      1
# Ameijoa Branca Nac. Ultracongelada                1
# Canivetes                                         1
# Miolo de ameijoa Zebra cozida                     1
# Miolo de ameijoa Zebra fervida ultracongelada     1
# da Ria                                            1
# Ostras frescas                                    1
# Ostra Fina (Crassostrea Gigas)                    1
# em Escabeche                                      1
# Branca congelada                                  1
# ...

# %%
# Amêijoa-branca
bivf1.loc[bivf1["Descrição da Amostra"].isin ( [ "Ameijoa branca inteira cozida 60/80",
                                                 "Ameijoa Branca Nac. Ultracongelada",
                                               "Branca congelada",
                                               "Ameijoa branca"] ), "Descrição da Amostra"] = "Amêijoa-branca"
bivf1["Descrição da Amostra"].value_counts()
# Out:
# Amêijoa-vietnamita                               29
# Mexilhão                                         11
# Amêijoa-japonesa                                  7
# Amêijoa-branca                                    4
# Amêijoa-boa                                       3
# Miolo de ameijoa                                  2
# Miolo de ameijoa Zebra cozida                     1
# Ostra Fina (Crassostrea Gigas)                    1
# Ostras frescas                                    1
# da Ria                                            1
# em escabeche                                      1
# Castanholas                                       1
# Pré-cozinhada                                     1
# Canivetes                                         1
# Miolo de ameijoa Zebra fervida ultracongelada     1
# em Escabeche                                      1
# Ultracongelado                                    1
# Name: Descrição da Amostra, dtype: int64

# %%
bivf1
# Out:
#      Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 0         True        63015      1803338  0088A3394P18      PNCA
# 1         True        21140      1306508  0091A3182L13      PNCA
# 2         True        24895      1400840  0015A3030L14      PNCA
# 3         True        63011      1803334  0077A3272P18      PNCA
# 4         True        63009      1803332  0073A3272P18      PNCA
# ..         ...          ...          ...           ...       ...
# 101       True        68277      1900753  0032A3148C19      PNCA
# 102       True        37918      1504722  0007A0384L15      PNCA
# 103       True        37686      1504483  0116A2232L15      PNCA
# 104       True        47411      1605181  0267A3051C16      PNCA
# 105       True        47542      1605309  0247A3051C16      PNCA
#
#           Tipo de Amostra Descrição da Amostra      Parâmetro    Res.Trat.  \
# 0                 Amêijoa   Amêijoa-vietnamita  Chumbo  (LFQ)          1,2
# ...

# %%
# Amêijoa-zebra
bivf1.loc[bivf1["Descrição da Amostra"].isin ( [ "Miolo de ameijoa Zebra cozida",
                                                 "Miolo de ameijoa Zebra fervida ultracongelada"] ), "Descrição da Amostra"] = "Amêijoa-zebra"
bivf1["Descrição da Amostra"].value_counts()
# Out:
# Amêijoa-vietnamita                29
# Mexilhão                          11
# Amêijoa-japonesa                   7
# Amêijoa-branca                     4
# Amêijoa-boa                        3
# Amêijoa-zebra                      2
# Miolo de ameijoa                   2
# em Escabeche                       1
# Canivetes                          1
# Pré-cozinhada                      1
# Castanholas                        1
# em escabeche                       1
# da Ria                             1
# Ostras frescas                     1
# Ostra Fina (Crassostrea Gigas)     1
# Ultracongelado                     1
# Name: Descrição da Amostra, dtype: int64

# %%
# Ostra
bivf1.loc[bivf1["Descrição da Amostra"].isin ( [ "Ostras frescas",
                                                 "Ostra Fina (Crassostrea Gigas)"] ), "Descrição da Amostra"] = "Ostra"
bivf1["Descrição da Amostra"].value_counts()
# Out:
# Amêijoa-vietnamita    29
# Mexilhão              11
# Amêijoa-japonesa       7
# Amêijoa-branca         4
# Amêijoa-boa            3
# Amêijoa-zebra          2
# Miolo de ameijoa       2
# Ostra                  2
# em Escabeche           1
# Canivetes              1
# Pré-cozinhada          1
# Castanholas            1
# em escabeche           1
# da Ria                 1
# Ultracongelado         1
# Name: Descrição da Amostra, dtype: int64

# %%
bivf1[bivf1["Descrição da Amostra"] == "em Escabeche"]
# Out:
#    Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 7       True        31660      1407501  0161A3030L14      PNCA
#
#                      Tipo de Amostra Descrição da Amostra      Parâmetro  \
# 7  Mexilhão, com outra transformação         em Escabeche  Chumbo  (LFQ)
#
#   Res.Trat. Unidade                Método          Data Resultado  \
# 7       0,6   mg/kg  QMI 02 de 14/03/2019 2014-11-20 13:20:08.227
#
#   Data Entrada Lab. Data Colheita                        Unidades Lab.
# 7        2014-11-05    2014-11-05  LFQ - Laboratório de Físico-Química

# %%
bivf1.loc[bivf1["Descrição da Amostra"].isin ( [ "em Escabeche",] ), "Descrição da Amostra"] = "Mexilhão"
bivf1["Descrição da Amostra"].value_counts()
# Out:
# Amêijoa-vietnamita    29
# Mexilhão              12
# Amêijoa-japonesa       7
# Amêijoa-branca         4
# Amêijoa-boa            3
# Amêijoa-zebra          2
# Miolo de ameijoa       2
# Ostra                  2
# Canivetes              1
# Pré-cozinhada          1
# Castanholas            1
# em escabeche           1
# da Ria                 1
# Ultracongelado         1
# Name: Descrição da Amostra, dtype: int64

# %%
bivf1[bivf1["Descrição da Amostra"] == "em escabeche"]
# Out:
#     Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 50       True        31917      1407755  0233A2232F14      PNCA
#
#                       Tipo de Amostra Descrição da Amostra      Parâmetro  \
# 50  Mexilhão, com outra transformação         em escabeche  Chumbo  (LFQ)
#
#    Res.Trat. Unidade                Método          Data Resultado  \
# 50      0,19   mg/kg  QMI 02 de 14/03/2019 2014-11-26 13:51:19.720
#
#    Data Entrada Lab. Data Colheita                        Unidades Lab.
# 50        2014-11-04    2014-11-03  LFQ - Laboratório de Físico-Química

# %%
bivf1.loc[bivf1["Descrição da Amostra"].isin ( [ "em escabeche",] ), "Descrição da Amostra"] = "Mexilhão"
bivf1["Descrição da Amostra"].value_counts()
# Out:
# Amêijoa-vietnamita    29
# Mexilhão              13
# Amêijoa-japonesa       7
# Amêijoa-branca         4
# Amêijoa-boa            3
# Amêijoa-zebra          2
# Miolo de ameijoa       2
# Ostra                  2
# Canivetes              1
# Pré-cozinhada          1
# Castanholas            1
# da Ria                 1
# Ultracongelado         1
# Name: Descrição da Amostra, dtype: int64

# %%
bivf1[bivf1["Descrição da Amostra"] == "Canivetes"]
# Out:
#     Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 21       True        25438      1401366  0041A2232L14      PNCA
#
#       Tipo de Amostra Descrição da Amostra      Parâmetro Res.Trat. Unidade  \
# 21  Longueirão, vivo             Canivetes  Chumbo  (LFQ)      0,38   mg/kg
#
#                   Método          Data Resultado Data Entrada Lab.  \
# 21  QMI 02 de 14/03/2019 2014-03-20 14:54:52.150        2014-02-25
#
#    Data Colheita                        Unidades Lab.
# 21    2014-02-25  LFQ - Laboratório de Físico-Química

# %%
bivf1.loc[bivf1["Descrição da Amostra"].isin ( [ "Canivetes",] ), "Descrição da Amostra"] = "Longueirão"
bivf1["Descrição da Amostra"].value_counts()
# Out:
# Amêijoa-vietnamita    29
# Mexilhão              13
# Amêijoa-japonesa       7
# Amêijoa-branca         4
# Amêijoa-boa            3
# Amêijoa-zebra          2
# Miolo de ameijoa       2
# Ostra                  2
# Longueirão             1
# Pré-cozinhada          1
# Castanholas            1
# da Ria                 1
# Ultracongelado         1
# Name: Descrição da Amostra, dtype: int64

# %%
bivf1[bivf1["Descrição da Amostra"] == "Pré-cozinhada"]
# Out:
#     Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 35       True        34365      1501204  0044A2242L15      PNCA
#
#                   Tipo de Amostra Descrição da Amostra      Parâmetro  \
# 35  Amêijoa-vietnamita, congelado        Pré-cozinhada  Chumbo  (LFQ)
#
#    Res.Trat. Unidade                Método          Data Resultado  \
# 35      0,28   mg/kg  QMI 02 de 14/03/2019 2015-03-11 12:49:51.023
#
#    Data Entrada Lab. Data Colheita                        Unidades Lab.
# 35        2015-02-19    2015-02-19  LFQ - Laboratório de Físico-Química

# %%
bivf1.loc[bivf1["Descrição da Amostra"].isin ( [ "Pré-cozinhada",] ), "Descrição da Amostra"] = "Amêijoa-vietnamita"
bivf1["Descrição da Amostra"].value_counts()
# Out:
# Amêijoa-vietnamita    30
# Mexilhão              13
# Amêijoa-japonesa       7
# Amêijoa-branca         4
# Amêijoa-boa            3
# Amêijoa-zebra          2
# Miolo de ameijoa       2
# Ostra                  2
# Longueirão             1
# Castanholas            1
# da Ria                 1
# Ultracongelado         1
# Name: Descrição da Amostra, dtype: int64

# %%
bivf1[bivf1["Descrição da Amostra"] == "da Ria"]
# Out:
#     Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 75       True        39812      1506588  0146A2242F15      PNCA
#
#    Tipo de Amostra Descrição da Amostra      Parâmetro Res.Trat. Unidade  \
# 75  Mexilhão, vivo               da Ria  Chumbo  (LFQ)      0,10   mg/kg
#
#                   Método          Data Resultado Data Entrada Lab.  \
# 75  QMI 02 de 14/03/2019 2015-09-22 15:42:36.083        2015-09-10
#
#    Data Colheita                        Unidades Lab.
# 75    2015-09-10  LFQ - Laboratório de Físico-Química

# %%
bivf1.loc[bivf1["Descrição da Amostra"].isin ( [ "da Ria",] ), "Descrição da Amostra"] = "Mexilhão"
bivf1["Descrição da Amostra"].value_counts()
# Out:
# Amêijoa-vietnamita    30
# Mexilhão              14
# Amêijoa-japonesa       7
# Amêijoa-branca         4
# Amêijoa-boa            3
# Amêijoa-zebra          2
# Miolo de ameijoa       2
# Ostra                  2
# Longueirão             1
# Castanholas            1
# Ultracongelado         1
# Name: Descrição da Amostra, dtype: int64

# %%
bivf1[bivf1["Descrição da Amostra"] == "Ultracongelado"]
# Out:
#     Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 98       True        34366      1501205  0042A2242L15      PNCA
#
#                   Tipo de Amostra Descrição da Amostra      Parâmetro  \
# 98  Amêijoa-vietnamita, congelado       Ultracongelado  Chumbo  (LFQ)
#
#       Res.Trat. Unidade                Método          Data Resultado  \
# 98  < 0,07 (LQ)   mg/kg  QMI 02 de 14/03/2019 2015-03-11 13:43:08.107
#
#    Data Entrada Lab. Data Colheita                        Unidades Lab.
# 98        2015-02-18    2015-02-18  LFQ - Laboratório de Físico-Química

# %%
bivf1.loc[bivf1["Descrição da Amostra"].isin ( ["Ultracongelado"] ), "Descrição da Amostra"] = "Amêijoa-vietnamita"
bivf1["Descrição da Amostra"].value_counts()
# Out:
# Amêijoa-vietnamita    31
# Mexilhão              14
# Amêijoa-japonesa       7
# Amêijoa-branca         4
# Amêijoa-boa            3
# Amêijoa-zebra          2
# Miolo de ameijoa       2
# Ostra                  2
# Longueirão             1
# Castanholas            1
# Name: Descrição da Amostra, dtype: int64

# %%
# Eliminar "Miolo de ameijo" pois não sei qual a espécie
bivf1[bivf1["Descrição da Amostra"] == "Miolo de ameijoa"]
# Out:
#     Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 56       True        67367      1807579  0225A3272P18      PNCA
# 60       True        67262      1807485  0218A3272P18      PNCA
#
#    Tipo de Amostra Descrição da Amostra      Parâmetro Res.Trat. Unidade  \
# 56         Amêijoa     Miolo de ameijoa  Chumbo  (LFQ)      0,17   mg/kg
# 60         Amêijoa     Miolo de ameijoa  Chumbo  (LFQ)      0,16   mg/kg
#
#                   Método      Data Resultado Data Entrada Lab. Data Colheita  \
# 56  QMI 02 de 14/03/2019 2019-01-17 14:09:00        2018-12-13    2018-12-06
# 60  QMI 02 de 14/03/2019 2019-01-02 18:01:00        2018-12-05    2018-12-03
#
#                           Unidades Lab.
# 56  LFQ - Laboratório de Físico-Química
# 60  LFQ - Laboratório de Físico-Química

# %%
miolo =bivf[bivf["Descrição da Amostra"] == "Miolo de ameijoa"]
bivf2= bivf1.drop(miolo.index)
bivf2["Descrição da Amostra"].value_counts()
# Out:
# Amêijoa-vietnamita    31
# Mexilhão              14
# Amêijoa-japonesa       7
# Amêijoa-branca         4
# Amêijoa-boa            3
# Amêijoa-zebra          2
# Ostra                  2
# Longueirão             1
# Castanholas            1
# Name: Descrição da Amostra, dtype: int64

# %%
bivf2["Descrição da Amostra"].value_counts()
# Out:
# Amêijoa-vietnamita    31
# Mexilhão              14
# Amêijoa-japonesa       7
# Amêijoa-branca         4
# Amêijoa-boa            3
# Amêijoa-zebra          2
# Ostra                  2
# Longueirão             1
# Castanholas            1
# Name: Descrição da Amostra, dtype: int64

# %%
bivf2
# Out:
#      Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 0         True        63015      1803338  0088A3394P18      PNCA
# 1         True        21140      1306508  0091A3182L13      PNCA
# 2         True        24895      1400840  0015A3030L14      PNCA
# 3         True        63011      1803334  0077A3272P18      PNCA
# 4         True        63009      1803332  0073A3272P18      PNCA
# ..         ...          ...          ...           ...       ...
# 101       True        68277      1900753  0032A3148C19      PNCA
# 102       True        37918      1504722  0007A0384L15      PNCA
# 103       True        37686      1504483  0116A2232L15      PNCA
# 104       True        47411      1605181  0267A3051C16      PNCA
# 105       True        47542      1605309  0247A3051C16      PNCA
#
#           Tipo de Amostra Descrição da Amostra      Parâmetro    Res.Trat.  \
# 0                 Amêijoa   Amêijoa-vietnamita  Chumbo  (LFQ)          1,2
# ...

# %% [markdown]
# # Tratar Valores LQ

# %%
bivf2[ (bivf2["Res.Trat."].str.contains("<",regex=False) | (bivf2["Res.Trat."].str.contains("LQ",regex=False,na=False)))]
# Out:
#      Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 84        True        21436      1306802  0214A2242L13      PNCA
# 85        True        21141      1306509  0093A3182L13      PNCA
# 86        True        45456      1603260  0042A3182L16      PNCA
# 87        True        45257      1603064  0060A3078F16      PNCA
# 88        True        23331      1308678  0121A3030S13      PNCA
# 90        True        21930      1307286  0169A3070L13      PNCA
# 91        True        22030      1307384  0182A2232L13      PNCA
# 92        True        34367      1501206  0043A2242L15      PNCA
# 93        True        34162      1501022  0031A2242L15      PNCA
# 96        True        42326      1600191  0003A3202P16      PNCA
# 97        True        66232      1806477  0139A3066F18      PNCA
# 98        True        34366      1501205  0042A2242L15      PNCA
# 99        True        36141      1502945  0127A3097C15      PNCA
# ...

# %% [markdown]
# __LQ=0.04__

# %%
bivf2.loc[(bivf2["Res.Trat."].str.contains("<",regex=False) | (bivf2["Res.Trat."].str.contains("LQ",regex=False, na=False))), "Res.Trat."]="0.04"

# %%
bivf2[ (bivf2["Res.Trat."].str.contains("<",regex=False) | (bivf2["Res.Trat."].str.contains("LQ",regex=False,na=False)))]
# Out:
# Empty DataFrame
# Columns: [Validado , ID Colheita, Nr. Amostra, Lote, Controlo , Tipo de Amostra, Descrição da Amostra, Parâmetro, Res.Trat., Unidade, Método, Data Resultado, Data Entrada Lab., Data Colheita, Unidades Lab.]
# Index: []

# %%
bivf2[bivf2["Res.Trat."]=="0.04"]
# Out:
#      Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 84        True        21436      1306802  0214A2242L13      PNCA
# 85        True        21141      1306509  0093A3182L13      PNCA
# 86        True        45456      1603260  0042A3182L16      PNCA
# 87        True        45257      1603064  0060A3078F16      PNCA
# 88        True        23331      1308678  0121A3030S13      PNCA
# 90        True        21930      1307286  0169A3070L13      PNCA
# 91        True        22030      1307384  0182A2232L13      PNCA
# 92        True        34367      1501206  0043A2242L15      PNCA
# 93        True        34162      1501022  0031A2242L15      PNCA
# 96        True        42326      1600191  0003A3202P16      PNCA
# 97        True        66232      1806477  0139A3066F18      PNCA
# 98        True        34366      1501205  0042A2242L15      PNCA
# 99        True        36141      1502945  0127A3097C15      PNCA
# ...

# %% [markdown]
# # Tratar Valores NaN na Coluna "Descrição da Amostra"

# %%
bivf2.isnull().sum()
# Out:
# Validado                 0
# ID Colheita              0
# Nr. Amostra              0
# Lote                     0
# Controlo                 0
# Tipo de Amostra          0
# Descrição da Amostra    36
# Parâmetro                0
# Res.Trat.                0
# Unidade                  0
# Método                   0
# Data Resultado           0
# Data Entrada Lab.        0
# Data Colheita            0
# Unidades Lab.            0
# dtype: int64

# %%
# Ver para cada tipo de amostra se tem valores NaN e substituir esses valores NaN

# %%
bivf2["Tipo de Amostra"].value_counts()
# Out:
# Amêijoa                              38
# Ostra, vivo                          13
# Mexilhão                             12
# Mexilhão, vivo                        8
# Amêijoa-japonesa, vivo                5
# Amêijoa-boa, vivo                     4
# Amêijoa-branca, vivo                  3
# Ostra                                 2
# Amêijoa, vivo                         2
# Amêijoa-vietnamita, congelado         2
# Lambujinha, vivo                      2
# Berbigão                              2
# Amêijoa-branca, congelado             2
# Mexilhão, com outra transformação     2
# Moluscos bivalves                     1
# Longueirão, vivo                      1
# Amêijoa-japonesa, congelado           1
# Longueirão                            1
# Name: Tipo de Amostra, dtype: int64

# %%
# Amêijoa
ameijoa=bivf2[bivf2["Tipo de Amostra"] == "Amêijoa"]
ameijoa
# Out:
#      Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 0         True        63015      1803338  0088A3394P18      PNCA
# 4         True        63009      1803332  0073A3272P18      PNCA
# 5         True        63016      1803339  0085A3394P18      PNCA
# 6         True        67341      1807553  0229A3272P18      PNCA
# 8         True        50787      1608488  0413A3051C16      PNCA
# 10        True        60671      1801302  0022A3066L18      PNCA
# 11        True        50817      1608516  0414A3051C16      PNCA
# 12        True        43687      1601525  0029A3030L16      PNCA
# 13        True        63010      1803333  0074A3272P18      PNCA
# 14        True        43686      1601524  0028A3030L16      PNCA
# 15        True        67351      1807563  0227A3272P18      PNCA
# 16        True        43685      1601523  0027A3030L16      PNCA
# 17        True        51546      1700594  0003A3078L17      PNCA
# ...

# %%
ameijoa.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    0
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
# Ostra, vivo
ostravivo= bivf2[bivf2["Tipo de Amostra"] == "Ostra, vivo"]
ostravivo
# Out:
#     Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 23       True        25931      1401845  0059A2242L14      PNCA
# 34       True        25038      1400976  0022A2242L14      PNCA
# 41       True        39802      1506578  0144A2242F15      PNCA
# 42       True        34163      1501023  0033A2242L15      PNCA
# 43       True        25203      1401141  0033A2242F14      PNCA
# 48       True        25906      1401820  0060A2232L14      PNCA
# 51       True        25721      1401638  0024A3182L14      PNCA
# 53       True        39763      1506547  0165A3030L15      PNCA
# 57       True        25238      1401176  0032A2232L14      PNCA
# 59       True        23329      1308676  0122A3030S13      PNCA
# 61       True        24896      1400841  0013A3030L14      PNCA
# 70       True        25720      1401637  0056A2232L14      PNCA
# 71       True        39803      1506579  0145A2242F15      PNCA
#
# ...

# %%
ostravivo.isnull().sum()
# Out:
# Validado                 0
# ID Colheita              0
# Nr. Amostra              0
# Lote                     0
# Controlo                 0
# Tipo de Amostra          0
# Descrição da Amostra    13
# Parâmetro                0
# Res.Trat.                0
# Unidade                  0
# Método                   0
# Data Resultado           0
# Data Entrada Lab.        0
# Data Colheita            0
# Unidades Lab.            0
# dtype: int64

# %%
d = {'Ostra, vivo': 'Ostra'}

bivf2['Descrição da Amostra'] = bivf2['Descrição da Amostra'].fillna(bivf2['Tipo de Amostra'].map(d))

# %%
bivf2.isnull().sum()
# Out:
# Validado                 0
# ID Colheita              0
# Nr. Amostra              0
# Lote                     0
# Controlo                 0
# Tipo de Amostra          0
# Descrição da Amostra    23
# Parâmetro                0
# Res.Trat.                0
# Unidade                  0
# Método                   0
# Data Resultado           0
# Data Entrada Lab.        0
# Data Colheita            0
# Unidades Lab.            0
# dtype: int64

# %%
# Mexilhão
mexilhao = bivf2[bivf2["Tipo de Amostra"] == "Mexilhão"]
mexilhao
# Out:
#      Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 3         True        63011      1803334  0077A3272P18      PNCA
# 19        True        63007      1803330  0078A3272P18      PNCA
# 31        True        62941      1803265  0086A3394P18      PNCA
# 44        True        48958      1606708  0147A3202P16      PNCA
# 45        True        66515      1806759  0049A3070L18      PNCA
# 68        True        63017      1803340  0084A3394P18      PNCA
# 77        True        48980      1606730  0152A0186P16      PNCA
# 79        True        47259      1605029  0265A3051C16      PNCA
# 81        True        66572      1806816  0054A3070L18      PNCA
# 87        True        45257      1603064  0060A3078F16      PNCA
# 104       True        47411      1605181  0267A3051C16      PNCA
# 105       True        47542      1605309  0247A3051C16      PNCA
#
#     Tipo de Amostra Descrição da Amostra      Parâmetro Res.Trat. Unidade  \
# ...

# %%
mexilhao.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    3
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
d = {'Mexilhão': 'Mexilhão'}

bivf2['Descrição da Amostra'] = bivf2['Descrição da Amostra'].fillna(bivf2['Tipo de Amostra'].map(d))

# %%
bivf2.isnull().sum()
# Out:
# Validado                 0
# ID Colheita              0
# Nr. Amostra              0
# Lote                     0
# Controlo                 0
# Tipo de Amostra          0
# Descrição da Amostra    20
# Parâmetro                0
# Res.Trat.                0
# Unidade                  0
# Método                   0
# Data Resultado           0
# Data Entrada Lab.        0
# Data Colheita            0
# Unidades Lab.            0
# dtype: int64

# %%
# Mexilhão, vivo
mexilhaovivo = bivf2[bivf2["Tipo de Amostra"] == "Mexilhão, vivo"]
mexilhaovivo
# Out:
#     Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 30       True        25439      1401367  0043A2232L14      PNCA
# 33       True        45413      1603220  0048A3030L16      PNCA
# 47       True        25037      1400975  0024A2242L14      PNCA
# 54       True        66440      1806684  0147A3066L18      PNCA
# 55       True        37687      1504484  0115A2232L15      PNCA
# 63       True        26059      1401970  0062A2232L14      PNCA
# 75       True        39812      1506588  0146A2242F15      PNCA
# 91       True        22030      1307384  0182A2232L13      PNCA
#
#    Tipo de Amostra Descrição da Amostra      Parâmetro    Res.Trat. Unidade  \
# 30  Mexilhão, vivo                  NaN  Chumbo  (LFQ)         0,30   mg/kg
# 33  Mexilhão, vivo                  NaN  Chumbo  (LFQ)         0,28   mg/kg
# 47  Mexilhão, vivo                  NaN  Chumbo  (LFQ)         0,22   mg/kg
# 54  Mexilhão, vivo             Mexilhão  Chumbo  (LFQ)         0,18   mg/kg
# ...

# %%
mexilhaovivo.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    5
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
d = {'Mexilhão, vivo': 'Mexilhão'}

bivf2['Descrição da Amostra'] = bivf2['Descrição da Amostra'].fillna(bivf2['Tipo de Amostra'].map(d))

# %%
bivf2.isnull().sum()
# Out:
# Validado                 0
# ID Colheita              0
# Nr. Amostra              0
# Lote                     0
# Controlo                 0
# Tipo de Amostra          0
# Descrição da Amostra    15
# Parâmetro                0
# Res.Trat.                0
# Unidade                  0
# Método                   0
# Data Resultado           0
# Data Entrada Lab.        0
# Data Colheita            0
# Unidades Lab.            0
# dtype: int64

# %%
# Amêijoa-japonesa, vivo
ameijoajapvivo = bivf2[bivf2["Tipo de Amostra"] == "Amêijoa-japonesa, vivo "]
ameijoajapvivo
# Out:
#     Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 36       True        21607      1306968  0163A2232E13      PNCA
# 76       True        34095      1500961  0029A2242L15      PNCA
# 84       True        21436      1306802  0214A2242L13      PNCA
# 85       True        21141      1306509  0093A3182L13      PNCA
# 88       True        23331      1308678  0121A3030S13      PNCA
#
#             Tipo de Amostra Descrição da Amostra      Parâmetro Res.Trat.  \
# 36  Amêijoa-japonesa, vivo                   NaN  Chumbo  (LFQ)      0,27
# 76  Amêijoa-japonesa, vivo                   NaN  Chumbo  (LFQ)      0,10
# 84  Amêijoa-japonesa, vivo                   NaN  Chumbo  (LFQ)      0.04
# 85  Amêijoa-japonesa, vivo                   NaN  Chumbo  (LFQ)      0.04
# 88  Amêijoa-japonesa, vivo                   NaN  Chumbo  (LFQ)      0.04
#
#    Unidade                Método          Data Resultado Data Entrada Lab.  \
# ...

# %%
ameijoajapvivo.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    5
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
d = {"Amêijoa-japonesa, vivo ": "Amêijoa-japonesa"}

bivf2['Descrição da Amostra'] = bivf2['Descrição da Amostra'].fillna(bivf2['Tipo de Amostra'].map(d))

# %%
bivf2.isnull().sum()
# Out:
# Validado                 0
# ID Colheita              0
# Nr. Amostra              0
# Lote                     0
# Controlo                 0
# Tipo de Amostra          0
# Descrição da Amostra    10
# Parâmetro                0
# Res.Trat.                0
# Unidade                  0
# Método                   0
# Data Resultado           0
# Data Entrada Lab.        0
# Data Colheita            0
# Unidades Lab.            0
# dtype: int64

# %%
# Amêijoa-boa, vivo
ameijoaboa = bivf2[bivf2["Tipo de Amostra"] == "Amêijoa-boa, vivo"]
ameijoaboa
# Out:
#      Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 67        True        23563      1308899  0259A2232L13      PNCA
# 90        True        21930      1307286  0169A3070L13      PNCA
# 93        True        34162      1501022  0031A2242L15      PNCA
# 103       True        37686      1504483  0116A2232L15      PNCA
#
#        Tipo de Amostra Descrição da Amostra      Parâmetro Res.Trat. Unidade  \
# 67   Amêijoa-boa, vivo                  NaN  Chumbo  (LFQ)      0,13   mg/kg
# 90   Amêijoa-boa, vivo          Amêijoa-boa  Chumbo  (LFQ)      0.04   mg/kg
# 93   Amêijoa-boa, vivo          Amêijoa-boa  Chumbo  (LFQ)      0.04   mg/kg
# 103  Amêijoa-boa, vivo          Amêijoa-boa  Chumbo  (LFQ)      0.04   mg/kg
#
#                    Método          Data Resultado Data Entrada Lab.  \
# 67   QMI 02 de 14/03/2019 2013-12-30 13:58:51.860        2013-12-10
# 90   QMI 02 de 14/03/2019 2013-11-12 00:00:00.000        2013-10-23
# ...

# %%
ameijoaboa.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    1
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
d = {"Amêijoa-boa, vivo": "Amêijoa-boa"}

bivf2['Descrição da Amostra'] = bivf2['Descrição da Amostra'].fillna(bivf2['Tipo de Amostra'].map(d))

# %%
bivf2.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    9
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
# Amêijoa-branca, vivo
ameijoabranca = bivf2[bivf2["Tipo de Amostra"] == "Amêijoa-branca, vivo"]
ameijoabranca
# Out:
#      Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 80        True        36109      1502913  0126A3097C15      PNCA
# 99        True        36141      1502945  0127A3097C15      PNCA
# 102       True        37918      1504722  0007A0384L15      PNCA
#
#           Tipo de Amostra Descrição da Amostra      Parâmetro    Res.Trat.  \
# 80   Amêijoa-branca, vivo                  NaN  Chumbo  (LFQ)         0,09
# 99   Amêijoa-branca, vivo                  NaN  Chumbo  (LFQ)  < 0,07 (LQ)
# 102  Amêijoa-branca, vivo                  NaN  Chumbo  (LFQ)  < 0,06 (LQ)
#
#     Unidade                Método          Data Resultado Data Entrada Lab.  \
# 80    mg/kg  QMI 02 de 14/03/2019 2015-05-05 09:02:06.397        2015-04-16
# 99    mg/kg  QMI 02 de 14/03/2019 2015-04-29 14:14:01.257        2015-04-20
# 102   mg/kg  QMI 02 de 14/03/2019 2015-07-06 11:01:50.310        2015-06-09
#
#     Data Colheita                        Unidades Lab.
# ...

# %%
ameijoabranca.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    3
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
d = {"Amêijoa-branca, vivo": "Amêijoa-branca"}

bivf2['Descrição da Amostra'] = bivf2['Descrição da Amostra'].fillna(bivf2['Tipo de Amostra'].map(d))

# %%
bivf2.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    6
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
#Ostra
ostra=bivf2[bivf2["Tipo de Amostra"] == "Ostra"]
ostra
# Out:
#     Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 78       True        49048      1606798  0146A3202P16      PNCA
# 82       True        48957      1606707  0008A0144P16      PNCA
#
#    Tipo de Amostra Descrição da Amostra      Parâmetro Res.Trat. Unidade  \
# 78           Ostra                Ostra  Chumbo  (LFQ)      0,10   mg/kg
# 82           Ostra                Ostra  Chumbo  (LFQ)      0,07   mg/kg
#
#                   Método          Data Resultado Data Entrada Lab.  \
# 78  QMI 02 de 14/03/2019 2016-11-15 17:12:22.873        2016-10-20
# 82  QMI 02 de 14/03/2019 2016-11-07 10:46:10.973        2016-10-20
#
#    Data Colheita                        Unidades Lab.
# 78    2016-10-14  LFQ - Laboratório de Físico-Química
# 82    2016-10-19  LFQ - Laboratório de Físico-Química

# %%
ostra.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    0
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
# Amêijoa, vivo
ameijoavivo = bivf2[bivf2["Tipo de Amostra"] == "Amêijoa, vivo"]
ameijoavivo
# Out:
#     Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 74       True        62624      1802957  0060A3030L18      PNCA
# 83       True        63059      1803382  0079A3078L18      PNCA
#
#    Tipo de Amostra Descrição da Amostra      Parâmetro Res.Trat. Unidade  \
# 74   Amêijoa, vivo     Amêijoa-japonesa  Chumbo  (LFQ)      0,10   mg/kg
# 83   Amêijoa, vivo     Amêijoa-japonesa  Chumbo  (LFQ)      0,07   mg/kg
#
#                   Método          Data Resultado Data Entrada Lab.  \
# 74  QMI 02 de 14/03/2019 2018-06-18 11:43:17.247        2018-05-09
# 83  QMI 02 de 14/03/2019 2018-06-19 09:53:40.930        2018-05-23
#
#    Data Colheita                        Unidades Lab.
# 74    2018-05-08  LFQ - Laboratório de Físico-Química
# 83    2018-05-23  LFQ - Laboratório de Físico-Química

# %%
ameijoavivo.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    0
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
# Amêijoa-vietnamita, congelado
ameijoaviet = bivf2[bivf2["Tipo de Amostra"] == "Amêijoa-vietnamita, congelado"]
ameijoaviet
# Out:
#     Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 35       True        34365      1501204  0044A2242L15      PNCA
# 98       True        34366      1501205  0042A2242L15      PNCA
#
#                   Tipo de Amostra Descrição da Amostra      Parâmetro  \
# 35  Amêijoa-vietnamita, congelado   Amêijoa-vietnamita  Chumbo  (LFQ)
# 98  Amêijoa-vietnamita, congelado   Amêijoa-vietnamita  Chumbo  (LFQ)
#
#    Res.Trat. Unidade                Método          Data Resultado  \
# 35      0,28   mg/kg  QMI 02 de 14/03/2019 2015-03-11 12:49:51.023
# 98      0.04   mg/kg  QMI 02 de 14/03/2019 2015-03-11 13:43:08.107
#
#    Data Entrada Lab. Data Colheita                        Unidades Lab.
# 35        2015-02-19    2015-02-19  LFQ - Laboratório de Físico-Química
# 98        2015-02-18    2015-02-18  LFQ - Laboratório de Físico-Química

# %%
ameijoaviet.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    0
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
# Lambujinha, vivo
lambujinha = bivf2[bivf2["Tipo de Amostra"] == "Lambujinha, vivo"]
lambujinha
# Out:
#    Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 1       True        21140      1306508  0091A3182L13      PNCA
# 2       True        24895      1400840  0015A3030L14      PNCA
#
#     Tipo de Amostra Descrição da Amostra      Parâmetro Res.Trat. Unidade  \
# 1  Lambujinha, vivo                  NaN  Chumbo  (LFQ)       1,1   mg/kg
# 2  Lambujinha, vivo                  NaN  Chumbo  (LFQ)       1,0   mg/kg
#
#                  Método          Data Resultado Data Entrada Lab.  \
# 1  QMI 02 de 14/03/2019 2013-11-04 00:00:00.000        2013-10-01
# 2  QMI 02 de 14/03/2019 2014-03-07 16:10:21.490        2014-02-04
#
#   Data Colheita                        Unidades Lab.
# 1    2013-10-01  LFQ - Laboratório de Físico-Química
# 2    2014-02-04  LFQ - Laboratório de Físico-Química

# %%
lambujinha.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    2
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
d = {"Lambujinha, vivo": "Lambujinha"}

bivf2['Descrição da Amostra'] = bivf2['Descrição da Amostra'].fillna(bivf2['Tipo de Amostra'].map(d))

# %%
bivf2.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    4
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
# Berbigão 
berbigão = bivf2[bivf2["Tipo de Amostra"] == "Berbigão"]
berbigão
# Out:
#     Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 20       True        62885      1803210  0068A3078F18      PNCA
# 58       True        62977      1803300  0074A3030L18      PNCA
#
#    Tipo de Amostra Descrição da Amostra      Parâmetro Res.Trat. Unidade  \
# 20        Berbigão                  NaN  Chumbo  (LFQ)       0,4   mg/kg
# 58        Berbigão                  NaN  Chumbo  (LFQ)      0,17   mg/kg
#
#                   Método          Data Resultado Data Entrada Lab.  \
# 20  QMI 02 de 14/03/2019 2018-06-19 10:58:31.167        2018-05-17
# 58  QMI 02 de 14/03/2019 2018-06-19 09:44:51.013        2018-05-21
#
#    Data Colheita                        Unidades Lab.
# 20    2018-05-15  LFQ - Laboratório de Físico-Química
# 58    2018-05-18  LFQ - Laboratório de Físico-Química

# %%
berbigão.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    2
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
d = {"Berbigão" : "Berbigão"}

bivf2['Descrição da Amostra'] = bivf2['Descrição da Amostra'].fillna(bivf2['Tipo de Amostra'].map(d))

# %%
bivf2.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    2
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
# Amêijoa-branca, congelado
ameijoabranca = bivf2[bivf2["Tipo de Amostra"] == "Amêijoa-branca, congelado"]
ameijoabranca
# Out:
#     Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 9        True        39997      1506769  0131A3202P15      PNCA
# 39       True        39988      1506761  0109A0186P15      PNCA
#
#               Tipo de Amostra Descrição da Amostra      Parâmetro Res.Trat.  \
# 9   Amêijoa-branca, congelado   Amêijoa-vietnamita  Chumbo  (LFQ)      0,52
# 39  Amêijoa-branca, congelado   Amêijoa-vietnamita  Chumbo  (LFQ)      0,26
#
#    Unidade                Método          Data Resultado Data Entrada Lab.  \
# 9    mg/kg  QMI 02 de 14/03/2019 2015-09-28 11:00:58.323        2015-09-17
# 39   mg/kg  QMI 02 de 14/03/2019 2015-09-28 10:58:32.437        2015-09-17
#
#    Data Colheita                        Unidades Lab.
# 9     2015-09-14  LFQ - Laboratório de Físico-Química
# 39    2015-09-14  LFQ - Laboratório de Físico-Química

# %%
ameijoabranca.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    0
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
# Mexilhão, com outra transformação
mexilhaotransf = bivf2[bivf2["Tipo de Amostra"] == "Mexilhão, com outra transformação"]
mexilhaotransf
# Out:
#     Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 7        True        31660      1407501  0161A3030L14      PNCA
# 50       True        31917      1407755  0233A2232F14      PNCA
#
#                       Tipo de Amostra Descrição da Amostra      Parâmetro  \
# 7   Mexilhão, com outra transformação             Mexilhão  Chumbo  (LFQ)
# 50  Mexilhão, com outra transformação             Mexilhão  Chumbo  (LFQ)
#
#    Res.Trat. Unidade                Método          Data Resultado  \
# 7        0,6   mg/kg  QMI 02 de 14/03/2019 2014-11-20 13:20:08.227
# 50      0,19   mg/kg  QMI 02 de 14/03/2019 2014-11-26 13:51:19.720
#
#    Data Entrada Lab. Data Colheita                        Unidades Lab.
# 7         2014-11-05    2014-11-05  LFQ - Laboratório de Físico-Química
# 50        2014-11-04    2014-11-03  LFQ - Laboratório de Físico-Química

# %%
mexilhaotransf.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    0
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
# Moluscos bivalves
molucosbiv= bivf2[bivf2["Tipo de Amostra"] == "Moluscos bivalves"]
molucosbiv.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    0
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
# Longueirão, vivo
longueiraovivo = bivf2[bivf2["Tipo de Amostra"] == "Longueirão, vivo "]
longueiraovivo
# Out:
#     Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 21       True        25438      1401366  0041A2232L14      PNCA
#
#       Tipo de Amostra Descrição da Amostra      Parâmetro Res.Trat. Unidade  \
# 21  Longueirão, vivo            Longueirão  Chumbo  (LFQ)      0,38   mg/kg
#
#                   Método          Data Resultado Data Entrada Lab.  \
# 21  QMI 02 de 14/03/2019 2014-03-20 14:54:52.150        2014-02-25
#
#    Data Colheita                        Unidades Lab.
# 21    2014-02-25  LFQ - Laboratório de Físico-Química

# %%
longueiraovivo.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    0
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
# Amêijoa-japonesa, congelado
ameijoajapocong= bivf2[bivf2["Tipo de Amostra"] == "Amêijoa-japonesa, congelado "]
ameijoajapocong
# Out:
#     Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 92       True        34367      1501206  0043A2242L15      PNCA
#
#                  Tipo de Amostra Descrição da Amostra      Parâmetro  \
# 92  Amêijoa-japonesa, congelado                   NaN  Chumbo  (LFQ)
#
#    Res.Trat. Unidade                Método          Data Resultado  \
# 92      0.04   mg/kg  QMI 02 de 14/03/2019 2015-03-11 13:47:21.343
#
#    Data Entrada Lab. Data Colheita                        Unidades Lab.
# 92        2015-02-18    2015-02-18  LFQ - Laboratório de Físico-Química

# %%
ameijoajapocong.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    1
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
d = {"Amêijoa-japonesa, congelado ": "Amêijoa-japonesa"}

bivf2['Descrição da Amostra'] = bivf2['Descrição da Amostra'].fillna(bivf2['Tipo de Amostra'].map(d))

# %%
bivf2.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    1
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
# Longueirão             
longueirao = bivf2[bivf2["Tipo de Amostra"] == "Longueirão"]
longueirao
# Out:
#     Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 97       True        66232      1806477  0139A3066F18      PNCA
#
#    Tipo de Amostra Descrição da Amostra      Parâmetro Res.Trat. Unidade  \
# 97      Longueirão                  NaN  Chumbo  (LFQ)      0.04   mg/kg
#
#                   Método      Data Resultado Data Entrada Lab. Data Colheita  \
# 97  QMI 02 de 14/03/2019 2019-01-17 14:07:00        2018-10-19    2018-10-18
#
#                           Unidades Lab.
# 97  LFQ - Laboratório de Físico-Química

# %%
longueirao.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    1
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %%
d = {"Longueirão": "Longueirão"}

bivf2['Descrição da Amostra'] = bivf2['Descrição da Amostra'].fillna(bivf2['Tipo de Amostra'].map(d))

# %%
bivf2.isnull().sum()
# Out:
# Validado                0
# ID Colheita             0
# Nr. Amostra             0
# Lote                    0
# Controlo                0
# Tipo de Amostra         0
# Descrição da Amostra    0
# Parâmetro               0
# Res.Trat.               0
# Unidade                 0
# Método                  0
# Data Resultado          0
# Data Entrada Lab.       0
# Data Colheita           0
# Unidades Lab.           0
# dtype: int64

# %% [markdown]
# # Eliminar colunas que não interessam

# %%
bivf2
# Out:
#      Validado   ID Colheita  Nr. Amostra          Lote Controlo   \
# 0         True        63015      1803338  0088A3394P18      PNCA
# 1         True        21140      1306508  0091A3182L13      PNCA
# 2         True        24895      1400840  0015A3030L14      PNCA
# 3         True        63011      1803334  0077A3272P18      PNCA
# 4         True        63009      1803332  0073A3272P18      PNCA
# ..         ...          ...          ...           ...       ...
# 101       True        68277      1900753  0032A3148C19      PNCA
# 102       True        37918      1504722  0007A0384L15      PNCA
# 103       True        37686      1504483  0116A2232L15      PNCA
# 104       True        47411      1605181  0267A3051C16      PNCA
# 105       True        47542      1605309  0247A3051C16      PNCA
#
#           Tipo de Amostra Descrição da Amostra      Parâmetro Res.Trat.  \
# 0                 Amêijoa   Amêijoa-vietnamita  Chumbo  (LFQ)       1,2
# ...

# %%
bivf2.drop(columns = ["Validado ","Lote","ID Colheita", "Controlo ", "Método", "Data Resultado", "Data Entrada Lab.", "Unidades Lab."], inplace=True)

# %%
bivf2
# Out:
#      Nr. Amostra       Tipo de Amostra Descrição da Amostra      Parâmetro  \
# 0        1803338               Amêijoa   Amêijoa-vietnamita  Chumbo  (LFQ)
# 1        1306508      Lambujinha, vivo           Lambujinha  Chumbo  (LFQ)
# 2        1400840      Lambujinha, vivo           Lambujinha  Chumbo  (LFQ)
# 3        1803334              Mexilhão             Mexilhão  Chumbo  (LFQ)
# 4        1803332               Amêijoa   Amêijoa-vietnamita  Chumbo  (LFQ)
# ..           ...                   ...                  ...            ...
# 101      1900753               Amêijoa     Amêijoa-japonesa  Chumbo  (LFQ)
# 102      1504722  Amêijoa-branca, vivo       Amêijoa-branca  Chumbo  (LFQ)
# 103      1504483     Amêijoa-boa, vivo          Amêijoa-boa  Chumbo  (LFQ)
# 104      1605181              Mexilhão             Mexilhão  Chumbo  (LFQ)
# 105      1605309              Mexilhão             Mexilhão  Chumbo  (LFQ)
#
#     Res.Trat. Unidade Data Colheita
# ...

# %%
bivf2 = bivf2.rename(columns={"Descrição da Amostra":"Espécie"})
bivf2
# Out:
#      Nr. Amostra       Tipo de Amostra             Espécie      Parâmetro  \
# 0        1803338               Amêijoa  Amêijoa-vietnamita  Chumbo  (LFQ)
# 1        1306508      Lambujinha, vivo          Lambujinha  Chumbo  (LFQ)
# 2        1400840      Lambujinha, vivo          Lambujinha  Chumbo  (LFQ)
# 3        1803334              Mexilhão            Mexilhão  Chumbo  (LFQ)
# 4        1803332               Amêijoa  Amêijoa-vietnamita  Chumbo  (LFQ)
# ..           ...                   ...                 ...            ...
# 101      1900753               Amêijoa    Amêijoa-japonesa  Chumbo  (LFQ)
# 102      1504722  Amêijoa-branca, vivo      Amêijoa-branca  Chumbo  (LFQ)
# 103      1504483     Amêijoa-boa, vivo         Amêijoa-boa  Chumbo  (LFQ)
# 104      1605181              Mexilhão            Mexilhão  Chumbo  (LFQ)
# 105      1605309              Mexilhão            Mexilhão  Chumbo  (LFQ)
#
#     Res.Trat. Unidade Data Colheita
# 0         1,2   mg/kg    2018-05-16
# ...

# %% [markdown]
# # Exportar dados para Excel

# %%
bivf2.to_excel("Dados_Bivalves_PNCA_Limpos_Final.xlsx")
