# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ipma = pd.read_excel("Dados IPMA Bivalves- Chumbo.xlsx")

# %%
ipma
# Out:
#      Nº Amostra Data de colheita Zona de\nProdução                Local  \
# 0         65/23       2023-01-30               EMR            Roncanito
# 1         60/23       2023-01-24                L2     Leça da Palmeira
# 2         50/23       2023-01-22               L5a      Praia dos Coxos
# 3         30/23       2023-01-12                L6  Praia da Samoqueira
# 4         21/23       2023-01-10              ETJ1  Vagem da Cana Verde
# ...         ...              ...               ...                  ...
# 2024      13189       2014-11-05              ESD2                 Abul
# 2025      13166       2014-10-29               EMR          Casa Branca
# 2026      13156       2014-10-27             RIAV3           Espinheiro
# 2027      13140       2014-10-22              ESD2                 Abul
# 2028      13041       2014-10-06               ETJ              Samouco
#
#                Espécie Pb\n(mg/kg)
# 0     Ostra-portuguesa      < 0,06
# 1        Ouriço-do-mar      < 0,06
# 2                 Lapa         0.1
# 3                 Lapa        0.22
# 4     Ostra-portuguesa        0.26
# ...                ...         ...
# 2024  Ostra-portuguesa        0.34
# 2025  Ostra-portuguesa        0.28
# 2026          Berbigão        0.41
# 2027  Ostra-portuguesa        0.09
# 2028        Lambujinha         2.2
#
# [2029 rows x 6 columns]

# %%
ipma.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2029 entries, 0 to 2028
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Nº Amostra        2029 non-null   object
#  1   Data de colheita  2029 non-null   datetime64[ns]
#  2   Zona de
# Produção  2025 non-null   object
#  3   Local             2029 non-null   object
#  4   Espécie           2029 non-null   object
#  5   Pb
# (mg/kg)        2029 non-null   object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 95.2+ KB

# %% [markdown]
# # Valores NaN

# %%
ipma.isnull().sum()
# Out:
# Nº Amostra           0
# Data de colheita     0
# Zona de\nProdução    4
# Local                0
# Espécie              0
# Pb\n(mg/kg)          0
# dtype: int64

# %% [markdown]
# # Limpar dados com "LD"

# %% [raw]
# Dados da Coluna "Pb\n(mg/kg)" que contenham a string "LD"

# %%
#Filtrar Dados que queremos limpar
limparLD = ipma[ipma["Pb\n(mg/kg)"].str.contains("LD", regex = False, na = False)]
limparLD
# Out:
#     Nº Amostra Data de colheita Zona de\nProdução             Local  \
# 368     981/21       2021-10-21               EMR         Roncanito
# 393     942/21       2021-10-13              OLH4          Garganta
# 396     927/21       2021-10-12                L2  Leça da Palmeira
# 397     928/21       2021-10-12                L1           Carreço
#
#               Espécie Pb\n(mg/kg)
# 368  Ostra-portuguesa          LD
# 393       Amêijoa-boa          LD
# 396     Ouriço-do-mar          LD
# 397     Ouriço-do-mar          LD

# %%
# Eliminar dados que queremos limpar
ipma2 = ipma.drop(limparLD.index)
ipma2.head()
# Out:
#   Nº Amostra Data de colheita Zona de\nProdução                Local  \
# 0      65/23       2023-01-30               EMR            Roncanito
# 1      60/23       2023-01-24                L2     Leça da Palmeira
# 2      50/23       2023-01-22               L5a      Praia dos Coxos
# 3      30/23       2023-01-12                L6  Praia da Samoqueira
# 4      21/23       2023-01-10              ETJ1  Vagem da Cana Verde
#
#             Espécie Pb\n(mg/kg)
# 0  Ostra-portuguesa      < 0,06
# 1     Ouriço-do-mar      < 0,06
# 2              Lapa         0.1
# 3              Lapa        0.22
# 4  Ostra-portuguesa        0.26

# %%
#Verificar se dados foram eliminados
ipma2[ipma2["Pb\n(mg/kg)"].str.contains("LD", regex = False, na = False)]
# Out:
# Empty DataFrame
# Columns: [Nº Amostra, Data de colheita, Zona de
# Produção, Local, Espécie, Pb
# (mg/kg)]
# Index: []

# %% [markdown]
# # Ánalise Explorátoria (Para Dados Categóricos)

# %% [raw]
# 1 - Ver Espécies:

# %%
ipma2["Espécie"].value_counts()
# Out:
# Lapa                      251
# Mexilhão                  227
# Ostra-portuguesa          221
# Amêijoa-boa               204
# Ostra-japonesa/gigante    167
# Lambujinha                155
# Amêijoa-japonesa          153
# Berbigão                  137
# Amêijoa-branca             71
# Longueirão                 66
# Conquilha                  53
# Amêijoa-macha              49
# Ostra-gigante              46
# Ouriço-do-mar              43
# Ostra-plana                32
# Castanhola                 28
# Ostra-gigante/japonesa     21
# Pé-de-burro                15
# Amêijola                   15
# Amêijoa-relógio            10
# Ostra                       8
# Canilha                     7
# Longueirão-direito          6
# Buzina                      5
# Buzinas                     4
# Amêijoa-asiática            4
# Amêijoa-cão                 4
# Pé-de-burrinho              4
# Vieira                      3
# Pé-de burrinho              2
# Taralhão                    2
# Zamburinha                  2
# Ostra-japonesa              2
# Búzio                       1
# Amêjoa-boa                  1
# Amêija-japonesa             1
# Mexihão                     1
# Leque                       1
# Burrié                      1
# Navalha                     1
# Ostra-gigas                 1
# Name: Espécie, dtype: int64

# %% [raw]
# Eliminar dados Categóricos que não Interessam:
#     Lapa, Buzinas, Canilha, Ouriço do mar, Buzina, Burrié,

# %%
#Limpar dados da Coluna "Espécie" = "Lapa"
lapa=ipma2[ipma2["Espécie"] == "Lapa"]
lapa
# Out:
#      Nº Amostra Data de colheita Zona de\nProdução                Local  \
# 2         50/23       2023-01-22               L5a      Praia dos Coxos
# 3         30/23       2023-01-12                L6  Praia da Samoqueira
# 6       1317/22       2022-12-18               L5a      Praia dos Coxos
# 7       1294/22       2022-12-12                L6  Praia da Samoqueira
# 14      1186/22       2022-11-07               L5a      Praia dos Coxos
# ...         ...              ...               ...                  ...
# 1656      16602       2017-04-11               L7A              Aljezur
# 1657      16603       2017-04-11                L4              Leirosa
# 1658      16604       2017-04-11                L4              Leirosa
# 1659      16605       2017-04-11                L6  Praia da Samoqueira
# 1701      16484       2017-03-09                L6  Praia da Samoqueira
#
#      Espécie Pb\n(mg/kg)
# 2       Lapa         0.1
# 3       Lapa        0.22
# 6       Lapa        0.28
# 7       Lapa        0.28
# 14      Lapa        0.11
# ...      ...         ...
# 1656    Lapa        0.51
# 1657    Lapa        0.34
# 1658    Lapa        0.34
# 1659    Lapa        0.24
# 1701    Lapa         0.3
#
# [251 rows x 6 columns]

# %%
ipma3 = ipma2.drop(lapa.index)
ipma3
# Out:
#      Nº Amostra Data de colheita Zona de\nProdução                Local  \
# 0         65/23       2023-01-30               EMR            Roncanito
# 1         60/23       2023-01-24                L2     Leça da Palmeira
# 4         21/23       2023-01-10              ETJ1  Vagem da Cana Verde
# 5       1324/22       2022-12-19            EMN ZN            Ponto 3 N
# 8       1295/22       2022-12-12               EMR            Roncanito
# ...         ...              ...               ...                  ...
# 2024      13189       2014-11-05              ESD2                 Abul
# 2025      13166       2014-10-29               EMR          Casa Branca
# 2026      13156       2014-10-27             RIAV3           Espinheiro
# 2027      13140       2014-10-22              ESD2                 Abul
# 2028      13041       2014-10-06               ETJ              Samouco
#
#                Espécie Pb\n(mg/kg)
# 0     Ostra-portuguesa      < 0,06
# 1        Ouriço-do-mar      < 0,06
# 4     Ostra-portuguesa        0.26
# 5             Berbigão        0.19
# 8     Ostra-portuguesa      < 0,06
# ...                ...         ...
# 2024  Ostra-portuguesa        0.34
# 2025  Ostra-portuguesa        0.28
# 2026          Berbigão        0.41
# 2027  Ostra-portuguesa        0.09
# 2028        Lambujinha         2.2
#
# [1774 rows x 6 columns]

# %%
#Limpar dados da Coluna "Espécie" = "Buzinas"
buzinas=ipma3[ipma3["Espécie"] == "Buzinas"]
buzinas
# Out:
#     Nº Amostra Data de colheita Zona de\nProdução            Local  Espécie  \
# 331    1213/21       2021-12-13              L7c2  Armação de Pêra  Buzinas
# 332    1177/21       2021-12-07              L7c1         Offshore  Buzinas
# 341    1148/21       2021-11-30              L7c2  Armação de Pera  Buzinas
# 343    1140/21       2021-11-23              L7c1         Offshore  Buzinas
#
#     Pb\n(mg/kg)
# 331      < 0,02
# 332      < 0,02
# 341        0.02
# 343      < 0,02

# %%
ipma4 = ipma3.drop(buzinas.index)
ipma4
# Out:
#      Nº Amostra Data de colheita Zona de\nProdução                Local  \
# 0         65/23       2023-01-30               EMR            Roncanito
# 1         60/23       2023-01-24                L2     Leça da Palmeira
# 4         21/23       2023-01-10              ETJ1  Vagem da Cana Verde
# 5       1324/22       2022-12-19            EMN ZN            Ponto 3 N
# 8       1295/22       2022-12-12               EMR            Roncanito
# ...         ...              ...               ...                  ...
# 2024      13189       2014-11-05              ESD2                 Abul
# 2025      13166       2014-10-29               EMR          Casa Branca
# 2026      13156       2014-10-27             RIAV3           Espinheiro
# 2027      13140       2014-10-22              ESD2                 Abul
# 2028      13041       2014-10-06               ETJ              Samouco
#
#                Espécie Pb\n(mg/kg)
# 0     Ostra-portuguesa      < 0,06
# 1        Ouriço-do-mar      < 0,06
# 4     Ostra-portuguesa        0.26
# 5             Berbigão        0.19
# 8     Ostra-portuguesa      < 0,06
# ...                ...         ...
# 2024  Ostra-portuguesa        0.34
# 2025  Ostra-portuguesa        0.28
# 2026          Berbigão        0.41
# 2027  Ostra-portuguesa        0.09
# 2028        Lambujinha         2.2
#
# [1770 rows x 6 columns]

# %%
#Limpar dados da Coluna "Espécie" = "Canilha"
canilha = ipma4[ipma4["Espécie"] == "Canilha"]
canilha
# Out:
#     Nº Amostra Data de colheita Zona de\nProdução               Local  \
# 161     416/22       2022-05-04                L9     Praia do Barril
# 296     101/22       2022-02-16                L9     Praia do Barril
# 387     936/21       2021-10-13                L9     Praia do Barril
# 422     860/21       2021-09-22                L9     Praia do Barril
# 488     746/21       2021-08-31              L7c2  Albufeira/Portimão
# 490     730/21       2021-08-25                L9     Praia do Barril
# 501     652/21       2021-07-22                L9     Praia do Barril
#
#      Espécie Pb\n(mg/kg)
# 161  Canilha        0.29
# 296  Canilha        0.15
# 387  Canilha        0.15
# 422  Canilha        0.27
# 488  Canilha        0.22
# 490  Canilha        0.14
# 501  Canilha      < 0.06

# %%
ipma5 = ipma4.drop(canilha.index)
ipma5
# Out:
#      Nº Amostra Data de colheita Zona de\nProdução                Local  \
# 0         65/23       2023-01-30               EMR            Roncanito
# 1         60/23       2023-01-24                L2     Leça da Palmeira
# 4         21/23       2023-01-10              ETJ1  Vagem da Cana Verde
# 5       1324/22       2022-12-19            EMN ZN            Ponto 3 N
# 8       1295/22       2022-12-12               EMR            Roncanito
# ...         ...              ...               ...                  ...
# 2024      13189       2014-11-05              ESD2                 Abul
# 2025      13166       2014-10-29               EMR          Casa Branca
# 2026      13156       2014-10-27             RIAV3           Espinheiro
# 2027      13140       2014-10-22              ESD2                 Abul
# 2028      13041       2014-10-06               ETJ              Samouco
#
#                Espécie Pb\n(mg/kg)
# 0     Ostra-portuguesa      < 0,06
# 1        Ouriço-do-mar      < 0,06
# 4     Ostra-portuguesa        0.26
# 5             Berbigão        0.19
# 8     Ostra-portuguesa      < 0,06
# ...                ...         ...
# 2024  Ostra-portuguesa        0.34
# 2025  Ostra-portuguesa        0.28
# 2026          Berbigão        0.41
# 2027  Ostra-portuguesa        0.09
# 2028        Lambujinha         2.2
#
# [1763 rows x 6 columns]

# %%
#Limpar dados da Coluna "Espécie" = "Ouriço-do-mar"
ouriço = ipma5[ipma5["Espécie"] == "Ouriço-do-mar"]
ouriço
# Out:
#      Nº Amostra Data de colheita Zona de\nProdução                    Local  \
# 1         60/23       2023-01-24                L2         Leça da Palmeira
# 27      1059/22       2022-10-06               L7a     Portinho da Arrifana
# 41      1049/22       2022-09-28                L1                  Carreço
# 48      1018/22       2022-09-26               L5a          Praia dos Coxos
# 146      621/22       2022-06-19               L5a          Praia dos Coxos
# 183      348/22       2022-04-26               L7a     Portinho da Arrifana
# 214      285/22       2022-04-05                L1                  Carreço
# 215      286/22       2022-04-05                L2         Leça da Palmeira
# 254      202/22       2022-03-20               L5a          Praia dos Coxos
# 412      873/21       2021-09-27               L5a          Praia dos Coxos
# 477      772/21       2021-09-07               L7a     Portinho da Arrifana
# 509      639/21       2021-07-18               L5a          Praia dos Coxos
# 596      258/21       2021-03-14               L5a          Praia dos Coxos
# 608      244/21       2021-03-09               L7a       Aljezur - Arrifana
# 639      194/21       2021-03-02                L2         Leça da Palmeira
# 640      195/21       2021-03-02                L1                  Carreço
# 676       41/21       2021-01-17               L5a          Praia dos Coxos
# 708     1227/20       2020-11-02               L5a          Praia dos Coxos
# 792      722/20       2020-09-08               L7a     Portinho da Arrifana
# 824      689/20       2020-09-01                L2         Leça da Palmeira
# 825      690/20       2020-09-01                L1                  Carreço
# 879      345/20       2020-05-05               L7a                  Aljezur
# 910      251/20       2020-03-24                L1                  Carreço
# 911      252/20       2020-03-24                L2         Leça da Palmeira
# 923      226/20       2020-03-11               L5a          Praia dos Coxos
# 1108      19566       2019-09-17               L5a          Praia dos Coxos
# 1151      19524       2019-09-03                L1                  Carreço
# 1152      19525       2019-09-03                L2         Leça da Palmeira
# 1199      19185       2019-05-06               L5a          Praia dos Coxos
# 1230      19067       2019-03-19                L1                  Carreço
# 1231      19068       2019-03-19                L2         Leça da Palmeira
# 1235      19073       2019-03-19               L7a                  Aljezur
# 1297      18844       2019-01-08                L6  Praia da Costa do Norte
# 1317      18528       2018-10-09                L1                  Carreço
# 1319      18531       2018-10-09                L2         Leça da Palmeira
# 1449      17793       2018-03-22               L7A                  Aljezur
# 1457      17777       2018-03-20                L2         Leça da Palmeira
# 1458      17778       2018-03-20                L1                  Carreço
# 1493      17735       2018-03-07               L5a    Praia dos Tombadoiros
# 1523      17442       2017-11-21                L2         Leça da Palmeira
# 1538      17267       2017-10-11               L7A                  Aljezur
# 1559      17151       2017-09-21                L5    Praia dos Tombadoiros
# 1566      17140       2017-09-20                L1                  Carreço
#
#             Espécie Pb\n(mg/kg)
# 1     Ouriço-do-mar      < 0,06
# 27    Ouriço-do-mar      < 0.06
# 41    Ouriço-do-mar      < 0.06
# 48    Ouriço-do-mar      < 0.06
# 146   Ouriço-do-mar      < 0,06
# 183   Ouriço-do-mar      < 0,06
# 214   Ouriço-do-mar      < 0,06
# 215   Ouriço-do-mar      < 0,06
# 254   Ouriço-do-mar        0.07
# 412   Ouriço-do-mar      < 0.06
# 477   Ouriço-do-mar      < 0.06
# 509   Ouriço-do-mar        0.11
# 596   Ouriço-do-mar        0.06
# 608   Ouriço-do-mar      < 0,06
# 639   Ouriço-do-mar      < 0,06
# 640   Ouriço-do-mar      < 0,02
# 676   Ouriço-do-mar      < 0,06
# 708   Ouriço-do-mar         0.5
# 792   Ouriço-do-mar      < 0,02
# 824   Ouriço-do-mar        0.02
# 825   Ouriço-do-mar        0.02
# 879   Ouriço-do-mar        0.07
# 910   Ouriço-do-mar      < 0,06
# 911   Ouriço-do-mar      < 0,06
# 923   Ouriço-do-mar        0.11
# 1108  Ouriço-do-mar      < 0,06
# 1151  Ouriço-do-mar      < 0,02
# 1152  Ouriço-do-mar      < 0,06
# 1199  Ouriço-do-mar      < 0,06
# 1230  Ouriço-do-mar      < 0,02
# 1231  Ouriço-do-mar        0.02
# 1235  Ouriço-do-mar      < 0,06
# 1297  Ouriço-do-mar      < 0,06
# 1317  Ouriço-do-mar      < 0,06
# 1319  Ouriço-do-mar      < 0,06
# 1449  Ouriço-do-mar        0.15
# 1457  Ouriço-do-mar        0.07
# 1458  Ouriço-do-mar        0.06
# 1493  Ouriço-do-mar        0.48
# 1523  Ouriço-do-mar      < 0,06
# 1538  Ouriço-do-mar        0.23
# 1559  Ouriço-do-mar        0.09
# 1566  Ouriço-do-mar        0.08

# %%
ipma6 = ipma5.drop(ouriço.index)
ipma6
# Out:
#      Nº Amostra Data de colheita Zona de\nProdução                Local  \
# 0         65/23       2023-01-30               EMR            Roncanito
# 4         21/23       2023-01-10              ETJ1  Vagem da Cana Verde
# 5       1324/22       2022-12-19            EMN ZN            Ponto 3 N
# 8       1295/22       2022-12-12               EMR            Roncanito
# 9       1282/22       2022-11-30              L7c2         Offshore MS1
# ...         ...              ...               ...                  ...
# 2024      13189       2014-11-05              ESD2                 Abul
# 2025      13166       2014-10-29               EMR          Casa Branca
# 2026      13156       2014-10-27             RIAV3           Espinheiro
# 2027      13140       2014-10-22              ESD2                 Abul
# 2028      13041       2014-10-06               ETJ              Samouco
#
#                Espécie Pb\n(mg/kg)
# 0     Ostra-portuguesa      < 0,06
# 4     Ostra-portuguesa        0.26
# 5             Berbigão        0.19
# 8     Ostra-portuguesa      < 0,06
# 9               Vieira        0.08
# ...                ...         ...
# 2024  Ostra-portuguesa        0.34
# 2025  Ostra-portuguesa        0.28
# 2026          Berbigão        0.41
# 2027  Ostra-portuguesa        0.09
# 2028        Lambujinha         2.2
#
# [1720 rows x 6 columns]

# %%
#Limpar dados da Coluna "Espécie" = "Buzina"
buzina = ipma6[ipma6["Espécie"] == "Buzina"]
buzina
# Out:
#     Nº Amostra Data de colheita Zona de\nProdução            Local Espécie  \
# 26     1058/22       2022-10-06                L8          Culatra  Buzina
# 150     505/22       2022-06-07              L7c1       Offshore 1  Buzina
# 152     486/22       2022-05-31              L7c2  Armação de Pêra  Buzina
# 423     861/21       2021-09-22                L9  Praia do Barril  Buzina
# 487     749/21       2021-09-02                L8          Culatra  Buzina
#
#     Pb\n(mg/kg)
# 26       < 0.02
# 150        0.02
# 152        0.02
# 423         0.5
# 487        0.06

# %%
ipma7 = ipma6.drop(buzina.index)
ipma7
# Out:
#      Nº Amostra Data de colheita Zona de\nProdução                Local  \
# 0         65/23       2023-01-30               EMR            Roncanito
# 4         21/23       2023-01-10              ETJ1  Vagem da Cana Verde
# 5       1324/22       2022-12-19            EMN ZN            Ponto 3 N
# 8       1295/22       2022-12-12               EMR            Roncanito
# 9       1282/22       2022-11-30              L7c2         Offshore MS1
# ...         ...              ...               ...                  ...
# 2024      13189       2014-11-05              ESD2                 Abul
# 2025      13166       2014-10-29               EMR          Casa Branca
# 2026      13156       2014-10-27             RIAV3           Espinheiro
# 2027      13140       2014-10-22              ESD2                 Abul
# 2028      13041       2014-10-06               ETJ              Samouco
#
#                Espécie Pb\n(mg/kg)
# 0     Ostra-portuguesa      < 0,06
# 4     Ostra-portuguesa        0.26
# 5             Berbigão        0.19
# 8     Ostra-portuguesa      < 0,06
# 9               Vieira        0.08
# ...                ...         ...
# 2024  Ostra-portuguesa        0.34
# 2025  Ostra-portuguesa        0.28
# 2026          Berbigão        0.41
# 2027  Ostra-portuguesa        0.09
# 2028        Lambujinha         2.2
#
# [1715 rows x 6 columns]

# %%
#Limpar dados da Coluna "Espécie" = "Buzina"
burrie = ipma7[ipma7["Espécie"] == "Burrié"]
burrie
# Out:
#      Nº Amostra Data de colheita Zona de\nProdução         Local Espécie  \
# 1081      19676       2019-10-15              ESD2  Carrasqueira  Burrié
#
#      Pb\n(mg/kg)
# 1081        0.06

# %%
ipma8 = ipma7.drop(burrie.index)
ipma8
# Out:
#      Nº Amostra Data de colheita Zona de\nProdução                Local  \
# 0         65/23       2023-01-30               EMR            Roncanito
# 4         21/23       2023-01-10              ETJ1  Vagem da Cana Verde
# 5       1324/22       2022-12-19            EMN ZN            Ponto 3 N
# 8       1295/22       2022-12-12               EMR            Roncanito
# 9       1282/22       2022-11-30              L7c2         Offshore MS1
# ...         ...              ...               ...                  ...
# 2024      13189       2014-11-05              ESD2                 Abul
# 2025      13166       2014-10-29               EMR          Casa Branca
# 2026      13156       2014-10-27             RIAV3           Espinheiro
# 2027      13140       2014-10-22              ESD2                 Abul
# 2028      13041       2014-10-06               ETJ              Samouco
#
#                Espécie Pb\n(mg/kg)
# 0     Ostra-portuguesa      < 0,06
# 4     Ostra-portuguesa        0.26
# 5             Berbigão        0.19
# 8     Ostra-portuguesa      < 0,06
# 9               Vieira        0.08
# ...                ...         ...
# 2024  Ostra-portuguesa        0.34
# 2025  Ostra-portuguesa        0.28
# 2026          Berbigão        0.41
# 2027  Ostra-portuguesa        0.09
# 2028        Lambujinha         2.2
#
# [1714 rows x 6 columns]

# %%
#Limpar dados da Coluna "Espécie" = "Búzio"
buzio= ipma8[ipma8["Espécie"] == "Búzio"]
buzio
# Out:
#     Nº Amostra Data de colheita Zona de\nProdução      Local Espécie  \
# 358    1027/21       2021-11-03              OLH2  Fortaleza   Búzio
#
#     Pb\n(mg/kg)
# 358      < 0,06

# %%
#Limpar dados da Coluna "Espécie" = "
ipma9 = ipma8.drop(buzio.index)
ipma9["Espécie"].value_counts()
# Out:
# Mexilhão                  227
# Ostra-portuguesa          221
# Amêijoa-boa               204
# Ostra-japonesa/gigante    167
# Lambujinha                155
# Amêijoa-japonesa          153
# Berbigão                  137
# Amêijoa-branca             71
# Longueirão                 66
# Conquilha                  53
# Amêijoa-macha              49
# Ostra-gigante              46
# Ostra-plana                32
# Castanhola                 28
# Ostra-gigante/japonesa     21
# Pé-de-burro                15
# Amêijola                   15
# Amêijoa-relógio            10
# Ostra                       8
# Longueirão-direito          6
# Amêijoa-cão                 4
# Pé-de-burrinho              4
# Amêijoa-asiática            4
# Vieira                      3
# Zamburinha                  2
# Taralhão                    2
# Pé-de burrinho              2
# Ostra-japonesa              2
# Navalha                     1
# Amêija-japonesa             1
# Leque                       1
# Mexihão                     1
# Amêjoa-boa                  1
# Ostra-gigas                 1
# Name: Espécie, dtype: int64

# %% [markdown]
# # Dados Duplicados

# %%
ipma9[ipma9.duplicated(["Nº Amostra", "Data de colheita", "Zona de\nProdução", "Local","Espécie", "Pb\n(mg/kg)"],keep=False)]
# Out:
#      Nº Amostra Data de colheita         Zona de\nProdução  \
# 309       30/22       2022-01-18                      ETJ1
# 310       30/22       2022-01-18                      ETJ1
# 311       20/22       2022-01-17                       LOB
# 312       21/22       2022-01-17                       LOB
# 313       22/22       2022-01-17                       LOB
# 314       23/22       2022-01-17                       LOB
# 315       24/22       2022-01-17                       LOB
# 316       25/22       2022-01-17                       LOB
# 317       26/22       2022-01-17                       LOB
# 318       20/22       2022-01-17                       LOB
# 319       21/22       2022-01-17                       LOB
# 320       22/22       2022-01-17                       LOB
# 321       23/22       2022-01-17                       LOB
# 322       24/22       2022-01-17                       LOB
# 323       25/22       2022-01-17                       LOB
# 324       26/22       2022-01-17                       LOB
# 327       10/22       2022-01-11                       EMR
# 328       10/22       2022-01-11                       EMR
# 1927      14116       2015-07-22  ESD1 Esteiro da Marateca
# 1928      14116       2015-07-22  ESD1 Esteiro da Marateca
# 1930      14061       2015-07-09  ESD1 Esteiro da Marateca
# 1931      14061       2015-07-09  ESD1 Esteiro da Marateca
# 1932      13924       2015-06-18                       EMR
# 1933      13924       2015-06-18                       EMR
# 1934      13911       2015-06-17  ESD1 Esteiro da Marateca
# 1935      13911       2015-06-17  ESD1 Esteiro da Marateca
# 1936      13889       2015-06-16                       ETJ
# 1937      13897       2015-06-16     ESD2 Canal de Alcácer
# 1938      13889       2015-06-16                       ETJ
# 1939      13897       2015-06-16     ESD2 Canal de Alcácer
# 1940      13852       2015-06-02     ESD2 Canal de Alcácer
# 1941      13852       2015-06-02     ESD2 Canal de Alcácer
# 1942      13824       2015-05-20                       EMR
# 1943      13824       2015-05-20                       EMR
# 1944      13810       2015-05-19                       ETJ
# 1945      13810       2015-05-19                       ETJ
# 1946      13807       2015-05-18     ESD2 Canal de Alcácer
# 1947      13807       2015-05-18     ESD2 Canal de Alcácer
# 1948      13781       2015-05-14  ESD1 Esteiro da Marateca
# 1949      13782       2015-05-14  ESD1 Esteiro da Marateca
# 1950      13781       2015-05-14  ESD1 Esteiro da Marateca
# 1951      13782       2015-05-14  ESD1 Esteiro da Marateca
# 1952      13771       2015-05-13  ESD1 Esteiro da Marateca
# 1953      13771       2015-05-13  ESD1 Esteiro da Marateca
#
#                         Local           Espécie Pb\n(mg/kg)
# 309                   Samouco        Lambujinha           2
# 310                   Samouco        Lambujinha           2
# 311   Frente à Escola de Vela          Mexilhão      < 0,06
# 312                   Greijau     Amêijoa-macha      < 0,06
# 313                  Espichel   Amêijoa-relógio        0.74
# 314                  Espichel       Amêijoa-boa        0.02
# 315                  Espichel        Longueirão      < 0,06
# 316                  Espichel  Amêijoa-japonesa      < 0,06
# 317                  Espichel          Berbigão        0.14
# 318   Frente à Escola de Vela          Mexilhão      < 0,06
# 319                   Greijau     Amêijoa-macha      < 0,06
# 320                  Espichel   Amêijoa-relógio        0.74
# 321                  Espichel       Amêijoa-boa        0.02
# 322                  Espichel        Longueirão      < 0,06
# 323                  Espichel  Amêijoa-japonesa      < 0,06
# 324                  Espichel          Berbigão        0.14
# 327                 Roncanito  Ostra-portuguesa      < 0,06
# 328                 Roncanito  Ostra-portuguesa      < 0,06
# 1927            Canal da Vaia  Ostra-portuguesa        0.13
# 1928            Canal da Vaia  Ostra-portuguesa        0.13
# 1930                   Gambia  Ostra-portuguesa         0.1
# 1931                   Gambia  Ostra-portuguesa         0.1
# 1932       Roncão/Casa Branca  Ostra-portuguesa        0.05
# 1933       Roncão/Casa Branca  Ostra-portuguesa        0.05
# 1934            Canal da Vaia  Ostra-portuguesa         0.1
# 1935            Canal da Vaia  Ostra-portuguesa         0.1
# 1936                  Samouco        Lambujinha           3
# 1937      Casas Novas/Batalha  Ostra-portuguesa        0.13
# 1938                  Samouco        Lambujinha           3
# 1939      Casas Novas/Batalha  Ostra-portuguesa        0.13
# 1940      Casas Novas/Batalha  Ostra-portuguesa        0.11
# 1941      Casas Novas/Batalha  Ostra-portuguesa        0.11
# 1942       Roncão/Casa Branca  Ostra-portuguesa        0.11
# 1943       Roncão/Casa Branca  Ostra-portuguesa        0.11
# 1944                  Samouco        Lambujinha         2.9
# 1945                  Samouco        Lambujinha         2.9
# 1946      Casas Novas/Batalha  Ostra-portuguesa        0.12
# 1947      Casas Novas/Batalha  Ostra-portuguesa        0.12
# 1948                 Faralhão       Ostra-plana        0.08
# 1949                 Faralhão  Ostra-portuguesa        0.12
# 1950                 Faralhão       Ostra-plana        0.08
# 1951                 Faralhão  Ostra-portuguesa        0.12
# 1952            Canal da Vaia  Ostra-portuguesa        0.18
# 1953            Canal da Vaia  Ostra-portuguesa        0.18

# %%
#Eliminar Dados Duplicados
ipma9.drop_duplicates(subset=["Nº Amostra","Data de colheita", "Zona de\nProdução", "Local","Espécie", "Pb\n(mg/kg)"], keep='first',inplace=True)

# %%
#Verificar se Duplicados foram apagados 
ipma9[ipma9.duplicated(["Nº Amostra", "Data de colheita", "Zona de\nProdução", "Local","Espécie", "Pb\n(mg/kg)"],keep=False)]
# Out:
# Empty DataFrame
# Columns: [Nº Amostra, Data de colheita, Zona de
# Produção, Local, Espécie, Pb
# (mg/kg)]
# Index: []

# %%
ipma9
# Out:
#      Nº Amostra Data de colheita Zona de\nProdução                Local  \
# 0         65/23       2023-01-30               EMR            Roncanito
# 4         21/23       2023-01-10              ETJ1  Vagem da Cana Verde
# 5       1324/22       2022-12-19            EMN ZN            Ponto 3 N
# 8       1295/22       2022-12-12               EMR            Roncanito
# 9       1282/22       2022-11-30              L7c2         Offshore MS1
# ...         ...              ...               ...                  ...
# 2024      13189       2014-11-05              ESD2                 Abul
# 2025      13166       2014-10-29               EMR          Casa Branca
# 2026      13156       2014-10-27             RIAV3           Espinheiro
# 2027      13140       2014-10-22              ESD2                 Abul
# 2028      13041       2014-10-06               ETJ              Samouco
#
#                Espécie Pb\n(mg/kg)
# 0     Ostra-portuguesa      < 0,06
# 4     Ostra-portuguesa        0.26
# 5             Berbigão        0.19
# 8     Ostra-portuguesa      < 0,06
# 9               Vieira        0.08
# ...                ...         ...
# 2024  Ostra-portuguesa        0.34
# 2025  Ostra-portuguesa        0.28
# 2026          Berbigão        0.41
# 2027  Ostra-portuguesa        0.09
# 2028        Lambujinha         2.2
#
# [1691 rows x 6 columns]

# %% [markdown]
# # Padronizar Dados

# %%
ipma9["Espécie"].value_counts()
# Out:
# Mexilhão                  226
# Ostra-portuguesa          210
# Amêijoa-boa               203
# Ostra-japonesa/gigante    167
# Lambujinha                152
# Amêijoa-japonesa          152
# Berbigão                  136
# Amêijoa-branca             71
# Longueirão                 65
# Conquilha                  53
# Amêijoa-macha              48
# Ostra-gigante              46
# Ostra-plana                31
# Castanhola                 28
# Ostra-gigante/japonesa     21
# Pé-de-burro                15
# Amêijola                   15
# Amêijoa-relógio             9
# Ostra                       8
# Longueirão-direito          6
# Amêijoa-cão                 4
# Pé-de-burrinho              4
# Amêijoa-asiática            4
# Vieira                      3
# Zamburinha                  2
# Taralhão                    2
# Pé-de burrinho              2
# Ostra-japonesa              2
# Navalha                     1
# Amêija-japonesa             1
# Leque                       1
# Mexihão                     1
# Amêjoa-boa                  1
# Ostra-gigas                 1
# Name: Espécie, dtype: int64

# %%
# Ostra-japonesa
ipma9.loc[ipma9["Espécie"].isin( ["Ostra-japonesa/gigante",
                                  "Ostra-gigante",
                                  "Ostra-gigante/japonesa",
                                  "Ostra-japonesa",
                                  "Ostra-gigas"] ) , "Espécie"] = "Ostra-japonesa"

# %%
ipma9["Espécie"].value_counts()
# Out:
# Ostra-japonesa        237
# Mexilhão              226
# Ostra-portuguesa      210
# Amêijoa-boa           203
# Lambujinha            152
# Amêijoa-japonesa      152
# Berbigão              136
# Amêijoa-branca         71
# Longueirão             65
# Conquilha              53
# Amêijoa-macha          48
# Ostra-plana            31
# Castanhola             28
# Amêijola               15
# Pé-de-burro            15
# Amêijoa-relógio         9
# Ostra                   8
# Longueirão-direito      6
# Amêijoa-asiática        4
# Amêijoa-cão             4
# Pé-de-burrinho          4
# Vieira                  3
# Taralhão                2
# Pé-de burrinho          2
# Zamburinha              2
# Amêjoa-boa              1
# Amêija-japonesa         1
# Mexihão                 1
# Leque                   1
# Navalha                 1
# Name: Espécie, dtype: int64

# %%
ostra=ipma9[ipma9["Espécie"]=="Ostra"]
ipma9.drop(ostra.index,inplace=True)

# %%
ipma9["Espécie"].value_counts()
# Out:
# Ostra-japonesa        237
# Mexilhão              226
# Ostra-portuguesa      210
# Amêijoa-boa           203
# Amêijoa-japonesa      152
# Lambujinha            152
# Berbigão              136
# Amêijoa-branca         71
# Longueirão             65
# Conquilha              53
# Amêijoa-macha          48
# Ostra-plana            31
# Castanhola             28
# Amêijola               15
# Pé-de-burro            15
# Amêijoa-relógio         9
# Longueirão-direito      6
# Amêijoa-asiática        4
# Pé-de-burrinho          4
# Amêijoa-cão             4
# Vieira                  3
# Zamburinha              2
# Taralhão                2
# Pé-de burrinho          2
# Amêjoa-boa              1
# Amêija-japonesa         1
# Mexihão                 1
# Leque                   1
# Navalha                 1
# Name: Espécie, dtype: int64

# %%
ipma9.loc[ipma8["Espécie"].isin( ["Longueirão-direito"]), "Espécie"] = "Longueirão"

# %%
ipma9["Espécie"].value_counts()
# Out:
# Ostra-japonesa      237
# Mexilhão            226
# Ostra-portuguesa    210
# Amêijoa-boa         203
# Lambujinha          152
# Amêijoa-japonesa    152
# Berbigão            136
# Longueirão           71
# Amêijoa-branca       71
# Conquilha            53
# Amêijoa-macha        48
# Ostra-plana          31
# Castanhola           28
# Pé-de-burro          15
# Amêijola             15
# Amêijoa-relógio       9
# Amêijoa-asiática      4
# Pé-de-burrinho        4
# Amêijoa-cão           4
# Vieira                3
# Zamburinha            2
# Taralhão              2
# Pé-de burrinho        2
# Amêjoa-boa            1
# Amêija-japonesa       1
# Mexihão               1
# Leque                 1
# Navalha               1
# Name: Espécie, dtype: int64

# %%
asiatica= ipma9[ipma9["Espécie"] == "Amêijoa-asiática"]
ipma10 = ipma9.drop(asiatica.index)

# %%
ipma10["Espécie"].value_counts()
# Out:
# Ostra-japonesa      237
# Mexilhão            226
# Ostra-portuguesa    210
# Amêijoa-boa         203
# Lambujinha          152
# Amêijoa-japonesa    152
# Berbigão            136
# Amêijoa-branca       71
# Longueirão           71
# Conquilha            53
# Amêijoa-macha        48
# Ostra-plana          31
# Castanhola           28
# Pé-de-burro          15
# Amêijola             15
# Amêijoa-relógio       9
# Amêijoa-cão           4
# Pé-de-burrinho        4
# Vieira                3
# Zamburinha            2
# Taralhão              2
# Pé-de burrinho        2
# Leque                 1
# Amêjoa-boa            1
# Amêija-japonesa       1
# Mexihão               1
# Navalha               1
# Name: Espécie, dtype: int64

# %%
zamburinha= ipma10[ipma10["Espécie"] == "Zamburinha"]
ipma11 = ipma10.drop(zamburinha.index)

# %%
ipma11["Espécie"].value_counts()
# Out:
# Ostra-japonesa      237
# Mexilhão            226
# Ostra-portuguesa    210
# Amêijoa-boa         203
# Lambujinha          152
# Amêijoa-japonesa    152
# Berbigão            136
# Longueirão           71
# Amêijoa-branca       71
# Conquilha            53
# Amêijoa-macha        48
# Ostra-plana          31
# Castanhola           28
# Pé-de-burro          15
# Amêijola             15
# Amêijoa-relógio       9
# Pé-de-burrinho        4
# Amêijoa-cão           4
# Vieira                3
# Taralhão              2
# Pé-de burrinho        2
# Leque                 1
# Amêjoa-boa            1
# Amêija-japonesa       1
# Mexihão               1
# Navalha               1
# Name: Espécie, dtype: int64

# %%
ipma11.loc[ipma11["Espécie"].isin( ["Leque"]), "Espécie"] = "Vieira"

# %%
ipma11["Espécie"].value_counts()
# Out:
# Ostra-japonesa      237
# Mexilhão            226
# Ostra-portuguesa    210
# Amêijoa-boa         203
# Lambujinha          152
# Amêijoa-japonesa    152
# Berbigão            136
# Longueirão           71
# Amêijoa-branca       71
# Conquilha            53
# Amêijoa-macha        48
# Ostra-plana          31
# Castanhola           28
# Amêijola             15
# Pé-de-burro          15
# Amêijoa-relógio       9
# Vieira                4
# Amêijoa-cão           4
# Pé-de-burrinho        4
# Taralhão              2
# Pé-de burrinho        2
# Amêjoa-boa            1
# Amêija-japonesa       1
# Mexihão               1
# Navalha               1
# Name: Espécie, dtype: int64

# %%
ipma11.loc[ipma11["Espécie"].isin( ["Amêjoa-boa"]), "Espécie"] = "Amêijoa-boa"
ipma11["Espécie"].value_counts()
# Out:
# Ostra-japonesa      237
# Mexilhão            226
# Ostra-portuguesa    210
# Amêijoa-boa         204
# Lambujinha          152
# Amêijoa-japonesa    152
# Berbigão            136
# Longueirão           71
# Amêijoa-branca       71
# Conquilha            53
# Amêijoa-macha        48
# Ostra-plana          31
# Castanhola           28
# Amêijola             15
# Pé-de-burro          15
# Amêijoa-relógio       9
# Vieira                4
# Amêijoa-cão           4
# Pé-de-burrinho        4
# Taralhão              2
# Pé-de burrinho        2
# Amêija-japonesa       1
# Mexihão               1
# Navalha               1
# Name: Espécie, dtype: int64

# %%
ipma11.loc[ipma11["Espécie"].isin( ["Amêija-japonesa"]), "Espécie"] = "Amêijoa-japonesa"
ipma11["Espécie"].value_counts()
# Out:
# Ostra-japonesa      237
# Mexilhão            226
# Ostra-portuguesa    210
# Amêijoa-boa         204
# Amêijoa-japonesa    153
# Lambujinha          152
# Berbigão            136
# Longueirão           71
# Amêijoa-branca       71
# Conquilha            53
# Amêijoa-macha        48
# Ostra-plana          31
# Castanhola           28
# Pé-de-burro          15
# Amêijola             15
# Amêijoa-relógio       9
# Amêijoa-cão           4
# Pé-de-burrinho        4
# Vieira                4
# Taralhão              2
# Pé-de burrinho        2
# Mexihão               1
# Navalha               1
# Name: Espécie, dtype: int64

# %%
ipma11.loc[ipma11["Espécie"].isin( ["Mexihão"]), "Espécie"] = "Mexilhão"
ipma11["Espécie"].value_counts()
# Out:
# Ostra-japonesa      237
# Mexilhão            227
# Ostra-portuguesa    210
# Amêijoa-boa         204
# Amêijoa-japonesa    153
# Lambujinha          152
# Berbigão            136
# Longueirão           71
# Amêijoa-branca       71
# Conquilha            53
# Amêijoa-macha        48
# Ostra-plana          31
# Castanhola           28
# Pé-de-burro          15
# Amêijola             15
# Amêijoa-relógio       9
# Amêijoa-cão           4
# Pé-de-burrinho        4
# Vieira                4
# Taralhão              2
# Pé-de burrinho        2
# Navalha               1
# Name: Espécie, dtype: int64

# %%
ipma11.loc[ipma11["Espécie"].isin( ["Navalha"]), "Espécie"] = "Longueirão"
ipma11["Espécie"].value_counts()
# Out:
# Ostra-japonesa      237
# Mexilhão            227
# Ostra-portuguesa    210
# Amêijoa-boa         204
# Amêijoa-japonesa    153
# Lambujinha          152
# Berbigão            136
# Longueirão           72
# Amêijoa-branca       71
# Conquilha            53
# Amêijoa-macha        48
# Ostra-plana          31
# Castanhola           28
# Amêijola             15
# Pé-de-burro          15
# Amêijoa-relógio       9
# Vieira                4
# Amêijoa-cão           4
# Pé-de-burrinho        4
# Taralhão              2
# Pé-de burrinho        2
# Name: Espécie, dtype: int64

# %%
ipma11.loc[ipma11["Espécie"].isin( ["Pé-de burrinho"]), "Espécie"] = "Pé-de-burrinho"
ipma11["Espécie"].value_counts()
# Out:
# Ostra-japonesa      237
# Mexilhão            227
# Ostra-portuguesa    210
# Amêijoa-boa         204
# Amêijoa-japonesa    153
# Lambujinha          152
# Berbigão            136
# Longueirão           72
# Amêijoa-branca       71
# Conquilha            53
# Amêijoa-macha        48
# Ostra-plana          31
# Castanhola           28
# Amêijola             15
# Pé-de-burro          15
# Amêijoa-relógio       9
# Pé-de-burrinho        6
# Vieira                4
# Amêijoa-cão           4
# Taralhão              2
# Name: Espécie, dtype: int64

# %% [markdown]
# # Tratar Dados LQ

# %%
LQ=ipma11[ (ipma11["Pb\n(mg/kg)"].str.contains("<",regex=False) | (ipma11["Pb\n(mg/kg)"].str.contains("LQ",regex=False, na=False)))]
LQ
# Out:
#      Nº Amostra Data de colheita Zona de\nProdução            Local  \
# 0         65/23       2023-01-30               EMR        Roncanito
# 8       1295/22       2022-12-12               EMR        Roncanito
# 21      1126/22       2022-10-20             RIAV3         Passagem
# 22      1106/22       2022-10-13              L7c2        Albufeira
# 23      1073/22       2022-10-10              ETJ2  Baliza de Ferro
# ...         ...              ...               ...              ...
# 1923      14258       2015-09-01               LAG     Vale da Lama
# 1924      14259       2015-09-01              POR2         Povoação
# 1982      13542       2015-03-10               LOB          Graijau
# 1985      13547       2015-03-10              LAG1     Vale da Lama
# 1997      13540       2015-03-09              TAV2     Quatro Águas
#
#                Espécie Pb\n(mg/kg)
# 0     Ostra-portuguesa      < 0,06
# 8     Ostra-portuguesa      < 0,06
# 21         Amêijoa-boa      < 0.06
# 22           Conquilha      < 0.06
# 23    Amêijoa-japonesa      < 0.06
# ...                ...         ...
# 1923       Amêijoa-boa      < 0,06
# 1924       Amêijoa-boa      < 0,06
# 1982  Amêijoa-japonesa      < 0,06
# 1985       Amêijoa-boa      < 0,06
# 1997       Amêijoa-boa      < 0,06
#
# [165 rows x 6 columns]

# %%
LQ.to_csv("IPMA_LQ.csv")

# %% [markdown]
# __LQ=0.01__

# %%
ipma11.loc[(ipma11["Pb\n(mg/kg)"].str.contains("<",regex=False) | (ipma11["Pb\n(mg/kg)"].str.contains("LQ",regex=False, na=False))), "Pb\n(mg/kg)"]="0.01"

# %%
ipma11[ipma11["Pb\n(mg/kg)"]=="0.01"]
# Out:
#      Nº Amostra Data de colheita Zona de\nProdução            Local  \
# 0         65/23       2023-01-30               EMR        Roncanito
# 8       1295/22       2022-12-12               EMR        Roncanito
# 21      1126/22       2022-10-20             RIAV3         Passagem
# 22      1106/22       2022-10-13              L7c2        Albufeira
# 23      1073/22       2022-10-10              ETJ2  Baliza de Ferro
# ...         ...              ...               ...              ...
# 1923      14258       2015-09-01               LAG     Vale da Lama
# 1924      14259       2015-09-01              POR2         Povoação
# 1982      13542       2015-03-10               LOB          Graijau
# 1985      13547       2015-03-10              LAG1     Vale da Lama
# 1997      13540       2015-03-09              TAV2     Quatro Águas
#
#                Espécie Pb\n(mg/kg)
# 0     Ostra-portuguesa        0.01
# 8     Ostra-portuguesa        0.01
# 21         Amêijoa-boa        0.01
# 22           Conquilha        0.01
# 23    Amêijoa-japonesa        0.01
# ...                ...         ...
# 1923       Amêijoa-boa        0.01
# 1924       Amêijoa-boa        0.01
# 1982  Amêijoa-japonesa        0.01
# 1985       Amêijoa-boa        0.01
# 1997       Amêijoa-boa        0.01
#
# [165 rows x 6 columns]

# %%
ipma11["Espécie"].value_counts()
# Out:
# Ostra-japonesa      237
# Mexilhão            227
# Ostra-portuguesa    210
# Amêijoa-boa         204
# Amêijoa-japonesa    153
# Lambujinha          152
# Berbigão            136
# Longueirão           72
# Amêijoa-branca       71
# Conquilha            53
# Amêijoa-macha        48
# Ostra-plana          31
# Castanhola           28
# Amêijola             15
# Pé-de-burro          15
# Amêijoa-relógio       9
# Pé-de-burrinho        6
# Vieira                4
# Amêijoa-cão           4
# Taralhão              2
# Name: Espécie, dtype: int64

# %% [markdown]
# # Exportar Dados para o Excel

# %%
ipma11.to_csv("IPMA_Dados_Limpos_Final.csv")
